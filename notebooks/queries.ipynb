# %% [markdown]
# # Queries on the knowledge graph

# %%
import sys
#!{sys.executable} -m pip install pandas oxrdflib Pygments

import pandas as pd
from IPython.display import display, HTML
from pygments import highlight
from pygments.lexers import SparqlLexer
from pygments.formatters import HtmlFormatter
from rdflib import Graph


def run_query(graph, query_path):
    try:
        with open(query_path, 'r') as file:
            query = file.read()
    except Exception as _e:
        print(f"No file for {query_path}")
        return
    results = graph.query(query)
    # Display the SPARQL query
    formatted_query = highlight(query, SparqlLexer(),
                                HtmlFormatter(style='solarized-dark', full=True, nobackground=True))
    display(HTML(formatted_query))
    # Convert results to a Pandas DataFrame
    res_list = []
    for row in results:
        res_list.append([str(item) for item in row])
    df = pd.DataFrame(res_list, columns=[str(var) for var in results.vars]) if len(res_list) > 0 else pd.DataFrame()
    # Display the DataFrame as a table in Jupyter Notebook
    display(HTML(df.to_html()))
    #return df

# %%
g = Graph(store='Oxigraph')
g.parse('../data/finance-kg.ttl', format='turtle')
# Out:
# <Graph identifier=N7b173d3dbce34d22a6a478101a0b049f (<class 'rdflib.graph.Graph'>)>

# %%
# count amount of triples
print(f'amount of triples: {len(g)}')
# Out:
# amount of triples: 239085

# %%
g
# Out:
# <Graph identifier=N7b173d3dbce34d22a6a478101a0b049f (<class 'rdflib.graph.Graph'>)>

# %%
run_query(g, '../queries/test.rq')
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #073642 }
# body .c { color: #586e75; font-style: italic } /* Comment */
# body .err { color: #839496; background-color: #dc322f } /* Error */
# body .esc { color: #839496 } /* Escape */
# body .g { color: #839496 } /* Generic */
# body .k { color: #859900 } /* Keyword */
# body .l { color: #839496 } /* Literal */
# body .n { color: #839496 } /* Name */
# body .o { color: #586e75 } /* Operator */
# body .x { color: #839496 } /* Other */
# body .p { color: #839496 } /* Punctuation */
# body .ch { color: #586e75; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #586e75; font-style: italic } /* Comment.Multiline */
# body .cp { color: #d33682 } /* Comment.Preproc */
# body .cpf { color: #586e75 } /* Comment.PreprocFile */
# body .c1 { color: #586e75; font-style: italic } /* Comment.Single */
# body .cs { color: #586e75; font-style: italic } /* Comment.Special */
# body .gd { color: #dc322f } /* Generic.Deleted */
# body .ge { color: #839496; font-style: italic } /* Generic.Emph */
# body .ges { color: #839496; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# body .gr { color: #dc322f } /* Generic.Error */
# body .gh { color: #839496; font-weight: bold } /* Generic.Heading */
# body .gi { color: #859900 } /* Generic.Inserted */
# body .go { color: #839496 } /* Generic.Output */
# body .gp { color: #268bd2; font-weight: bold } /* Generic.Prompt */
# body .gs { color: #839496; font-weight: bold } /* Generic.Strong */
# body .gu { color: #839496; text-decoration: underline } /* Generic.Subheading */
# body .gt { color: #268bd2 } /* Generic.Traceback */
# body .kc { color: #2aa198 } /* Keyword.Constant */
# body .kd { color: #2aa198 } /* Keyword.Declaration */
# body .kn { color: #cb4b16 } /* Keyword.Namespace */
# body .kp { color: #859900 } /* Keyword.Pseudo */
# body .kr { color: #859900 } /* Keyword.Reserved */
# body .kt { color: #b58900 } /* Keyword.Type */
# body .ld { color: #839496 } /* Literal.Date */
# body .m { color: #2aa198 } /* Literal.Number */
# body .s { color: #2aa198 } /* Literal.String */
# body .na { color: #839496 } /* Name.Attribute */
# body .nb { color: #268bd2 } /* Name.Builtin */
# body .nc { color: #268bd2 } /* Name.Class */
# body .no { color: #268bd2 } /* Name.Constant */
# body .nd { color: #268bd2 } /* Name.Decorator */
# body .ni { color: #268bd2 } /* Name.Entity */
# body .ne { color: #268bd2 } /* Name.Exception */
# body .nf { color: #268bd2 } /* Name.Function */
# body .nl { color: #268bd2 } /* Name.Label */
# body .nn { color: #268bd2 } /* Name.Namespace */
# body .nx { color: #839496 } /* Name.Other */
# body .py { color: #839496 } /* Name.Property */
# body .nt { color: #268bd2 } /* Name.Tag */
# body .nv { color: #268bd2 } /* Name.Variable */
# body .ow { color: #859900 } /* Operator.Word */
# body .pm { color: #839496 } /* Punctuation.Marker */
# body .w { color: #839496 } /* Text.Whitespace */
# body .mb { color: #2aa198 } /* Literal.Number.Bin */
# body .mf { color: #2aa198 } /* Literal.Number.Float */
# body .mh { color: #2aa198 } /* Literal.Number.Hex */
# body .mi { color: #2aa198 } /* Literal.Number.Integer */
# body .mo { color: #2aa198 } /* Literal.Number.Oct */
# body .sa { color: #2aa198 } /* Literal.String.Affix */
# body .sb { color: #2aa198 } /* Literal.String.Backtick */
# body .sc { color: #2aa198 } /* Literal.String.Char */
# body .dl { color: #2aa198 } /* Literal.String.Delimiter */
# body .sd { color: #586e75 } /* Literal.String.Doc */
# body .s2 { color: #2aa198 } /* Literal.String.Double */
# body .se { color: #2aa198 } /* Literal.String.Escape */
# body .sh { color: #2aa198 } /* Literal.String.Heredoc */
# body .si { color: #2aa198 } /* Literal.String.Interpol */
# body .sx { color: #2aa198 } /* Literal.String.Other */
# body .sr { color: #cb4b16 } /* Literal.String.Regex */
# body .s1 { color: #2aa198 } /* Literal.String.Single */
# body .ss { color: #2aa198 } /* Literal.String.Symbol */
# body .bp { color: #268bd2 } /* Name.Builtin.Pseudo */
# body .fm { color: #268bd2 } /* Name.Function.Magic */
# body .vc { color: #268bd2 } /* Name.Variable.Class */
# body .vg { color: #268bd2 } /* Name.Variable.Global */
# body .vi { color: #268bd2 } /* Name.Variable.Instance */
# body .vm { color: #268bd2 } /* Name.Variable.Magic */
# body .il { color: #2aa198 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">SELECT</span> <span class="nv">?sector</span> <span class="nv">?sectorName</span>
# <span class="k">WHERE</span> <span class="p">{</span>
#   <span class="nv">?sector</span> <span class="k">a</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">Industry</span> <span class="p">.</span>
#   <span class="nv">?sector</span> <span class="nn">rdfs</span><span class="p">:</span><span class="nt">label</span> <span class="nv">?sectorName</span> <span class="p">.</span>
# <span class="p">}</span>
# </pre></div>
# </body>
# </html>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sector</th>
#       <th>sectorName</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>https://finance.yahoo.com/sectors/energy/oil-gas-equipment-services</td>
#       <td>Oil &amp; Gas Equipment &amp; Services</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>https://finance.yahoo.com/sectors/healthcare/healthcare-plans</td>
#       <td>Healthcare Plans</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>https://finance.yahoo.com/sectors/consumer-cyclical/auto-manufacturers</td>
#       <td>Auto Manufacturers</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>https://finance.yahoo.com/sectors/industrials/trucking</td>
#       <td>Trucking</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>https://finance.yahoo.com/sectors/consumer-cyclical/apparel-manufacturing</td>
#       <td>Apparel Manufacturing</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>https://finance.yahoo.com/sectors/consumer-defensive/food-distribution</td>
#       <td>Food Distribution</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>https://finance.yahoo.com/sectors/communication-services/telecom-services</td>
#       <td>Telecom Services</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>https://finance.yahoo.com/sectors/consumer-defensive/discount-stores</td>
#       <td>Discount Stores</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>https://finance.yahoo.com/sectors/financial-services/insurance-property-casualty</td>
#       <td>Insurance - Property &amp; Casualty</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>https://finance.yahoo.com/sectors/utilities/utilities-independent-power-producers</td>
#       <td>Utilities - Independent Power Producers</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>https://finance.yahoo.com/sectors/financial-services/insurance-specialty</td>
#       <td>Insurance - Specialty</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>https://finance.yahoo.com/sectors/technology/software-infrastructure</td>
#       <td>Software - Infrastructure</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>https://finance.yahoo.com/sectors/consumer-defensive/grocery-stores</td>
#       <td>Grocery Stores</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>https://finance.yahoo.com/sectors/financial-services/asset-management</td>
#       <td>Asset Management</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>https://finance.yahoo.com/sectors/real-estate/reit-diversified</td>
#       <td>REIT - Diversified</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>https://finance.yahoo.com/sectors/financial-services/shell-companies</td>
#       <td>Shell Companies</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>https://finance.yahoo.com/sectors/financial-services/insurance-diversified</td>
#       <td>Insurance - Diversified</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>https://finance.yahoo.com/sectors/industrials/integrated-freight-logistics</td>
#       <td>Integrated Freight &amp; Logistics</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>https://finance.yahoo.com/sectors/technology/scientific-technical-instruments</td>
#       <td>Scientific &amp; Technical Instruments</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>https://finance.yahoo.com/sectors/basic-materials/lumber-wood-production</td>
#       <td>Lumber &amp; Wood Production</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>https://finance.yahoo.com/sectors/energy/oil-gas-ep</td>
#       <td>Oil &amp; Gas E&amp;P</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>https://finance.yahoo.com/sectors/consumer-cyclical/specialty-retail</td>
#       <td>Specialty Retail</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>https://finance.yahoo.com/sectors/healthcare/diagnostics-research</td>
#       <td>Diagnostics &amp; Research</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>https://finance.yahoo.com/sectors/financial-services/credit-services</td>
#       <td>Credit Services</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>https://finance.yahoo.com/sectors/industrials/metal-fabrication</td>
#       <td>Metal Fabrication</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>https://finance.yahoo.com/sectors/consumer-cyclical/auto-truck-dealerships</td>
#       <td>Auto &amp; Truck Dealerships</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>https://finance.yahoo.com/sectors/real-estate/reit-mortgage</td>
#       <td>REIT - Mortgage</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>https://finance.yahoo.com/sectors/utilities/utilities-diversified</td>
#       <td>Utilities - Diversified</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>https://finance.yahoo.com/sectors/technology/software-application</td>
#       <td>Software - Application</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>https://finance.yahoo.com/sectors/energy/uranium</td>
#       <td>Uranium</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>https://finance.yahoo.com/sectors/utilities/utilities-regulated-water</td>
#       <td>Utilities - Regulated Water</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>https://finance.yahoo.com/sectors/technology/solar</td>
#       <td>Solar</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>https://finance.yahoo.com/sectors/basic-materials/silver</td>
#       <td>Silver</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>https://finance.yahoo.com/sectors/industrials/farm-heavy-construction-machinery</td>
#       <td>Farm &amp; Heavy Construction Machinery</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>https://finance.yahoo.com/sectors/communication-services/entertainment</td>
#       <td>Entertainment</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>https://finance.yahoo.com/sectors/real-estate/reit-office</td>
#       <td>REIT - Office</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>https://finance.yahoo.com/sectors/financial-services/capital-markets</td>
#       <td>Capital Markets</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>https://finance.yahoo.com/sectors/communication-services/electronic-gaming-multimedia</td>
#       <td>Electronic Gaming &amp; Multimedia</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>https://finance.yahoo.com/sectors/industrials/airports-air-services</td>
#       <td>Airports &amp; Air Services</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>https://finance.yahoo.com/sectors/financial-services/insurance-life</td>
#       <td>Insurance - Life</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>https://finance.yahoo.com/sectors/healthcare/medical-care-facilities</td>
#       <td>Medical Care Facilities</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>https://finance.yahoo.com/sectors/technology/communication-equipment</td>
#       <td>Communication Equipment</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>https://finance.yahoo.com/sectors/industrials/waste-management</td>
#       <td>Waste Management</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>https://finance.yahoo.com/sectors/consumer-cyclical/gambling</td>
#       <td>Gambling</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>https://finance.yahoo.com/sectors/consumer-defensive/confectioners</td>
#       <td>Confectioners</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>https://finance.yahoo.com/sectors/healthcare/pharmaceutical-retailers</td>
#       <td>Pharmaceutical Retailers</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>https://finance.yahoo.com/sectors/real-estate/reit-healthcare-facilities</td>
#       <td>REIT - Healthcare Facilities</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>https://finance.yahoo.com/sectors/energy/oil-gas-drilling</td>
#       <td>Oil &amp; Gas Drilling</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>https://finance.yahoo.com/sectors/consumer-cyclical/footwear-accessories</td>
#       <td>Footwear &amp; Accessories</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>https://finance.yahoo.com/sectors/consumer-cyclical/lodging</td>
#       <td>Lodging</td>
#     </tr>
#     <

# %%
run_query(g, '../queries/recommendation.rq')
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #073642 }
# body .c { color: #586e75; font-style: italic } /* Comment */
# body .err { color: #839496; background-color: #dc322f } /* Error */
# body .esc { color: #839496 } /* Escape */
# body .g { color: #839496 } /* Generic */
# body .k { color: #859900 } /* Keyword */
# body .l { color: #839496 } /* Literal */
# body .n { color: #839496 } /* Name */
# body .o { color: #586e75 } /* Operator */
# body .x { color: #839496 } /* Other */
# body .p { color: #839496 } /* Punctuation */
# body .ch { color: #586e75; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #586e75; font-style: italic } /* Comment.Multiline */
# body .cp { color: #d33682 } /* Comment.Preproc */
# body .cpf { color: #586e75 } /* Comment.PreprocFile */
# body .c1 { color: #586e75; font-style: italic } /* Comment.Single */
# body .cs { color: #586e75; font-style: italic } /* Comment.Special */
# body .gd { color: #dc322f } /* Generic.Deleted */
# body .ge { color: #839496; font-style: italic } /* Generic.Emph */
# body .ges { color: #839496; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# body .gr { color: #dc322f } /* Generic.Error */
# body .gh { color: #839496; font-weight: bold } /* Generic.Heading */
# body .gi { color: #859900 } /* Generic.Inserted */
# body .go { color: #839496 } /* Generic.Output */
# body .gp { color: #268bd2; font-weight: bold } /* Generic.Prompt */
# body .gs { color: #839496; font-weight: bold } /* Generic.Strong */
# body .gu { color: #839496; text-decoration: underline } /* Generic.Subheading */
# body .gt { color: #268bd2 } /* Generic.Traceback */
# body .kc { color: #2aa198 } /* Keyword.Constant */
# body .kd { color: #2aa198 } /* Keyword.Declaration */
# body .kn { color: #cb4b16 } /* Keyword.Namespace */
# body .kp { color: #859900 } /* Keyword.Pseudo */
# body .kr { color: #859900 } /* Keyword.Reserved */
# body .kt { color: #b58900 } /* Keyword.Type */
# body .ld { color: #839496 } /* Literal.Date */
# body .m { color: #2aa198 } /* Literal.Number */
# body .s { color: #2aa198 } /* Literal.String */
# body .na { color: #839496 } /* Name.Attribute */
# body .nb { color: #268bd2 } /* Name.Builtin */
# body .nc { color: #268bd2 } /* Name.Class */
# body .no { color: #268bd2 } /* Name.Constant */
# body .nd { color: #268bd2 } /* Name.Decorator */
# body .ni { color: #268bd2 } /* Name.Entity */
# body .ne { color: #268bd2 } /* Name.Exception */
# body .nf { color: #268bd2 } /* Name.Function */
# body .nl { color: #268bd2 } /* Name.Label */
# body .nn { color: #268bd2 } /* Name.Namespace */
# body .nx { color: #839496 } /* Name.Other */
# body .py { color: #839496 } /* Name.Property */
# body .nt { color: #268bd2 } /* Name.Tag */
# body .nv { color: #268bd2 } /* Name.Variable */
# body .ow { color: #859900 } /* Operator.Word */
# body .pm { color: #839496 } /* Punctuation.Marker */
# body .w { color: #839496 } /* Text.Whitespace */
# body .mb { color: #2aa198 } /* Literal.Number.Bin */
# body .mf { color: #2aa198 } /* Literal.Number.Float */
# body .mh { color: #2aa198 } /* Literal.Number.Hex */
# body .mi { color: #2aa198 } /* Literal.Number.Integer */
# body .mo { color: #2aa198 } /* Literal.Number.Oct */
# body .sa { color: #2aa198 } /* Literal.String.Affix */
# body .sb { color: #2aa198 } /* Literal.String.Backtick */
# body .sc { color: #2aa198 } /* Literal.String.Char */
# body .dl { color: #2aa198 } /* Literal.String.Delimiter */
# body .sd { color: #586e75 } /* Literal.String.Doc */
# body .s2 { color: #2aa198 } /* Literal.String.Double */
# body .se { color: #2aa198 } /* Literal.String.Escape */
# body .sh { color: #2aa198 } /* Literal.String.Heredoc */
# body .si { color: #2aa198 } /* Literal.String.Interpol */
# body .sx { color: #2aa198 } /* Literal.String.Other */
# body .sr { color: #cb4b16 } /* Literal.String.Regex */
# body .s1 { color: #2aa198 } /* Literal.String.Single */
# body .ss { color: #2aa198 } /* Literal.String.Symbol */
# body .bp { color: #268bd2 } /* Name.Builtin.Pseudo */
# body .fm { color: #268bd2 } /* Name.Function.Magic */
# body .vc { color: #268bd2 } /* Name.Variable.Class */
# body .vg { color: #268bd2 } /* Name.Variable.Global */
# body .vi { color: #268bd2 } /* Name.Variable.Instance */
# body .vm { color: #268bd2 } /* Name.Variable.Magic */
# body .il { color: #2aa198 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">PREFIX</span> <span class="nn">finance</span><span class="p">:</span> <span class="nl">&lt;https://w3id.org/finance/&gt;</span>
#
# <span class="c"># get all recommendations for a company MSFT and get recommendation value</span>
# <span class="k">SELECT</span> <span class="nv">?recommendationValue</span>
# <span class="k">WHERE</span> <span class="p">{</span>
#   <span class="nv">?company</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">hasRecommendation</span> <span class="nv">?recommendation</span> <span class="p">.</span>
#   <span class="nv">?recommendation</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">hasStrongBuyCount</span> <span class="nv">?recommendationValue</span> <span class="p">.</span>
#   <span class="nv">?company</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">hasTicker</span> <span class="s">&quot;MSFT&quot;</span> <span class="p">.</span>
# <span class="p">}</span>
# </pre></div>
# </body>
# </html>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>recommendationValue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>14</td>
#     </tr>
#   </tbody>
# </table>

# %%
run_query(g, '../queries/earnings_date.rq')
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #073642 }
# body .c { color: #586e75; font-style: italic } /* Comment */
# body .err { color: #839496; background-color: #dc322f } /* Error */
# body .esc { color: #839496 } /* Escape */
# body .g { color: #839496 } /* Generic */
# body .k { color: #859900 } /* Keyword */
# body .l { color: #839496 } /* Literal */
# body .n { color: #839496 } /* Name */
# body .o { color: #586e75 } /* Operator */
# body .x { color: #839496 } /* Other */
# body .p { color: #839496 } /* Punctuation */
# body .ch { color: #586e75; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #586e75; font-style: italic } /* Comment.Multiline */
# body .cp { color: #d33682 } /* Comment.Preproc */
# body .cpf { color: #586e75 } /* Comment.PreprocFile */
# body .c1 { color: #586e75; font-style: italic } /* Comment.Single */
# body .cs { color: #586e75; font-style: italic } /* Comment.Special */
# body .gd { color: #dc322f } /* Generic.Deleted */
# body .ge { color: #839496; font-style: italic } /* Generic.Emph */
# body .ges { color: #839496; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# body .gr { color: #dc322f } /* Generic.Error */
# body .gh { color: #839496; font-weight: bold } /* Generic.Heading */
# body .gi { color: #859900 } /* Generic.Inserted */
# body .go { color: #839496 } /* Generic.Output */
# body .gp { color: #268bd2; font-weight: bold } /* Generic.Prompt */
# body .gs { color: #839496; font-weight: bold } /* Generic.Strong */
# body .gu { color: #839496; text-decoration: underline } /* Generic.Subheading */
# body .gt { color: #268bd2 } /* Generic.Traceback */
# body .kc { color: #2aa198 } /* Keyword.Constant */
# body .kd { color: #2aa198 } /* Keyword.Declaration */
# body .kn { color: #cb4b16 } /* Keyword.Namespace */
# body .kp { color: #859900 } /* Keyword.Pseudo */
# body .kr { color: #859900 } /* Keyword.Reserved */
# body .kt { color: #b58900 } /* Keyword.Type */
# body .ld { color: #839496 } /* Literal.Date */
# body .m { color: #2aa198 } /* Literal.Number */
# body .s { color: #2aa198 } /* Literal.String */
# body .na { color: #839496 } /* Name.Attribute */
# body .nb { color: #268bd2 } /* Name.Builtin */
# body .nc { color: #268bd2 } /* Name.Class */
# body .no { color: #268bd2 } /* Name.Constant */
# body .nd { color: #268bd2 } /* Name.Decorator */
# body .ni { color: #268bd2 } /* Name.Entity */
# body .ne { color: #268bd2 } /* Name.Exception */
# body .nf { color: #268bd2 } /* Name.Function */
# body .nl { color: #268bd2 } /* Name.Label */
# body .nn { color: #268bd2 } /* Name.Namespace */
# body .nx { color: #839496 } /* Name.Other */
# body .py { color: #839496 } /* Name.Property */
# body .nt { color: #268bd2 } /* Name.Tag */
# body .nv { color: #268bd2 } /* Name.Variable */
# body .ow { color: #859900 } /* Operator.Word */
# body .pm { color: #839496 } /* Punctuation.Marker */
# body .w { color: #839496 } /* Text.Whitespace */
# body .mb { color: #2aa198 } /* Literal.Number.Bin */
# body .mf { color: #2aa198 } /* Literal.Number.Float */
# body .mh { color: #2aa198 } /* Literal.Number.Hex */
# body .mi { color: #2aa198 } /* Literal.Number.Integer */
# body .mo { color: #2aa198 } /* Literal.Number.Oct */
# body .sa { color: #2aa198 } /* Literal.String.Affix */
# body .sb { color: #2aa198 } /* Literal.String.Backtick */
# body .sc { color: #2aa198 } /* Literal.String.Char */
# body .dl { color: #2aa198 } /* Literal.String.Delimiter */
# body .sd { color: #586e75 } /* Literal.String.Doc */
# body .s2 { color: #2aa198 } /* Literal.String.Double */
# body .se { color: #2aa198 } /* Literal.String.Escape */
# body .sh { color: #2aa198 } /* Literal.String.Heredoc */
# body .si { color: #2aa198 } /* Literal.String.Interpol */
# body .sx { color: #2aa198 } /* Literal.String.Other */
# body .sr { color: #cb4b16 } /* Literal.String.Regex */
# body .s1 { color: #2aa198 } /* Literal.String.Single */
# body .ss { color: #2aa198 } /* Literal.String.Symbol */
# body .bp { color: #268bd2 } /* Name.Builtin.Pseudo */
# body .fm { color: #268bd2 } /* Name.Function.Magic */
# body .vc { color: #268bd2 } /* Name.Variable.Class */
# body .vg { color: #268bd2 } /* Name.Variable.Global */
# body .vi { color: #268bd2 } /* Name.Variable.Instance */
# body .vm { color: #268bd2 } /* Name.Variable.Magic */
# body .il { color: #2aa198 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="c"># earning dates for MSFT</span>
# <span class="k">SELECT</span> <span class="nv">?earningsDate</span> <span class="nv">?date</span>
# <span class="k">WHERE</span> <span class="p">{</span>
#   <span class="nv">?company</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">hasTicker</span> <span class="s">&quot;MSFT&quot;</span> <span class="p">.</span>
#   <span class="nv">?company</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">hasEarningsDate</span> <span class="nv">?earningsDate</span> <span class="p">.</span>
#   <span class="nv">?earningsDate</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">hasDate</span> <span class="nv">?date</span> <span class="p">.</span>
# <span class="p">}</span>
# </pre></div>
# </body>
# </html>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>earningsDate</th>
#       <th>date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>https://finance.yahoo.com/quote/MSFT/earnings/2024-10-22</td>
#       <td>2024-10-22</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>https://finance.yahoo.com/quote/MSFT/earnings/2023-04-25</td>
#       <td>2023-04-25</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>https://finance.yahoo.com/quote/MSFT/earnings/2022-04-26</td>
#       <td>2022-04-26</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>https://finance.yahoo.com/quote/MSFT/earnings/2024-07-23</td>
#       <td>2024-07-23</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>https://finance.yahoo.com/quote/MSFT/earnings/2023-01-24</td>
#       <td>2023-01-24</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>https://finance.yahoo.com/quote/MSFT/earnings/2023-07-25</td>
#       <td>2023-07-25</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>https://finance.yahoo.com/quote/MSFT/earnings/2024-04-23</td>
#       <td>2024-04-23</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>https://finance.yahoo.com/quote/MSFT/earnings/2025-01-28</td>
#       <td>2025-01-28</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>https://finance.yahoo.com/quote/MSFT/earnings/2022-07-26</td>
#       <td>2022-07-26</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>https://finance.yahoo.com/quote/MSFT/earnings/2022-10-25</td>
#       <td>2022-10-25</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>https://finance.yahoo.com/quote/MSFT/earnings/2023-10-24</td>
#       <td>2023-10-24</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>https://finance.yahoo.com/quote/MSFT/earnings/2024-01-30</td>
#       <td>2024-01-30</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Validation queries

# %%
run_query(g, '../queries/validation/etf_company_count.rq')
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #073642 }
# body .c { color: #586e75; font-style: italic } /* Comment */
# body .err { color: #839496; background-color: #dc322f } /* Error */
# body .esc { color: #839496 } /* Escape */
# body .g { color: #839496 } /* Generic */
# body .k { color: #859900 } /* Keyword */
# body .l { color: #839496 } /* Literal */
# body .n { color: #839496 } /* Name */
# body .o { color: #586e75 } /* Operator */
# body .x { color: #839496 } /* Other */
# body .p { color: #839496 } /* Punctuation */
# body .ch { color: #586e75; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #586e75; font-style: italic } /* Comment.Multiline */
# body .cp { color: #d33682 } /* Comment.Preproc */
# body .cpf { color: #586e75 } /* Comment.PreprocFile */
# body .c1 { color: #586e75; font-style: italic } /* Comment.Single */
# body .cs { color: #586e75; font-style: italic } /* Comment.Special */
# body .gd { color: #dc322f } /* Generic.Deleted */
# body .ge { color: #839496; font-style: italic } /* Generic.Emph */
# body .ges { color: #839496; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# body .gr { color: #dc322f } /* Generic.Error */
# body .gh { color: #839496; font-weight: bold } /* Generic.Heading */
# body .gi { color: #859900 } /* Generic.Inserted */
# body .go { color: #839496 } /* Generic.Output */
# body .gp { color: #268bd2; font-weight: bold } /* Generic.Prompt */
# body .gs { color: #839496; font-weight: bold } /* Generic.Strong */
# body .gu { color: #839496; text-decoration: underline } /* Generic.Subheading */
# body .gt { color: #268bd2 } /* Generic.Traceback */
# body .kc { color: #2aa198 } /* Keyword.Constant */
# body .kd { color: #2aa198 } /* Keyword.Declaration */
# body .kn { color: #cb4b16 } /* Keyword.Namespace */
# body .kp { color: #859900 } /* Keyword.Pseudo */
# body .kr { color: #859900 } /* Keyword.Reserved */
# body .kt { color: #b58900 } /* Keyword.Type */
# body .ld { color: #839496 } /* Literal.Date */
# body .m { color: #2aa198 } /* Literal.Number */
# body .s { color: #2aa198 } /* Literal.String */
# body .na { color: #839496 } /* Name.Attribute */
# body .nb { color: #268bd2 } /* Name.Builtin */
# body .nc { color: #268bd2 } /* Name.Class */
# body .no { color: #268bd2 } /* Name.Constant */
# body .nd { color: #268bd2 } /* Name.Decorator */
# body .ni { color: #268bd2 } /* Name.Entity */
# body .ne { color: #268bd2 } /* Name.Exception */
# body .nf { color: #268bd2 } /* Name.Function */
# body .nl { color: #268bd2 } /* Name.Label */
# body .nn { color: #268bd2 } /* Name.Namespace */
# body .nx { color: #839496 } /* Name.Other */
# body .py { color: #839496 } /* Name.Property */
# body .nt { color: #268bd2 } /* Name.Tag */
# body .nv { color: #268bd2 } /* Name.Variable */
# body .ow { color: #859900 } /* Operator.Word */
# body .pm { color: #839496 } /* Punctuation.Marker */
# body .w { color: #839496 } /* Text.Whitespace */
# body .mb { color: #2aa198 } /* Literal.Number.Bin */
# body .mf { color: #2aa198 } /* Literal.Number.Float */
# body .mh { color: #2aa198 } /* Literal.Number.Hex */
# body .mi { color: #2aa198 } /* Literal.Number.Integer */
# body .mo { color: #2aa198 } /* Literal.Number.Oct */
# body .sa { color: #2aa198 } /* Literal.String.Affix */
# body .sb { color: #2aa198 } /* Literal.String.Backtick */
# body .sc { color: #2aa198 } /* Literal.String.Char */
# body .dl { color: #2aa198 } /* Literal.String.Delimiter */
# body .sd { color: #586e75 } /* Literal.String.Doc */
# body .s2 { color: #2aa198 } /* Literal.String.Double */
# body .se { color: #2aa198 } /* Literal.String.Escape */
# body .sh { color: #2aa198 } /* Literal.String.Heredoc */
# body .si { color: #2aa198 } /* Literal.String.Interpol */
# body .sx { color: #2aa198 } /* Literal.String.Other */
# body .sr { color: #cb4b16 } /* Literal.String.Regex */
# body .s1 { color: #2aa198 } /* Literal.String.Single */
# body .ss { color: #2aa198 } /* Literal.String.Symbol */
# body .bp { color: #268bd2 } /* Name.Builtin.Pseudo */
# body .fm { color: #268bd2 } /* Name.Function.Magic */
# body .vc { color: #268bd2 } /* Name.Variable.Class */
# body .vg { color: #268bd2 } /* Name.Variable.Global */
# body .vi { color: #268bd2 } /* Name.Variable.Instance */
# body .vm { color: #268bd2 } /* Name.Variable.Magic */
# body .il { color: #2aa198 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">SELECT</span> <span class="nv">?etfName</span> <span class="p">(</span><span class="nf">COUNT</span><span class="p">(</span><span class="nv">?company</span><span class="p">)</span> <span class="k">AS</span> <span class="nv">?companyCount</span><span class="p">)</span>
# <span class="k">WHERE</span> <span class="p">{</span>
#   <span class="nv">?etf</span> <span class="k">a</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">ETF</span> <span class="p">;</span>
#        <span class="nn">finance</span><span class="p">:</span><span class="nt">hasCompany</span> <span class="nv">?company</span> <span class="p">;</span>
#        <span class="nn">finance</span><span class="p">:</span><span class="nt">hasName</span> <span class="nv">?etfName</span> <span class="p">.</span>
# <span class="p">}</span>
# <span class="k">GROUP BY</span> <span class="nv">?etf</span> <span class="nv">?etfName</span>
# </pre></div>
# </body>
# </html>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>etfName</th>
#       <th>companyCount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>iShares Core S&amp;P 500 ETF</td>
#       <td>502</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>iShares MSCI World ETF</td>
#       <td>1441</td>
#     </tr>
#   </tbody>
# </table>

# %%
run_query(g, '../queries/validation/company_amount.rq')
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #073642 }
# body .c { color: #586e75; font-style: italic } /* Comment */
# body .err { color: #839496; background-color: #dc322f } /* Error */
# body .esc { color: #839496 } /* Escape */
# body .g { color: #839496 } /* Generic */
# body .k { color: #859900 } /* Keyword */
# body .l { color: #839496 } /* Literal */
# body .n { color: #839496 } /* Name */
# body .o { color: #586e75 } /* Operator */
# body .x { color: #839496 } /* Other */
# body .p { color: #839496 } /* Punctuation */
# body .ch { color: #586e75; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #586e75; font-style: italic } /* Comment.Multiline */
# body .cp { color: #d33682 } /* Comment.Preproc */
# body .cpf { color: #586e75 } /* Comment.PreprocFile */
# body .c1 { color: #586e75; font-style: italic } /* Comment.Single */
# body .cs { color: #586e75; font-style: italic } /* Comment.Special */
# body .gd { color: #dc322f } /* Generic.Deleted */
# body .ge { color: #839496; font-style: italic } /* Generic.Emph */
# body .ges { color: #839496; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# body .gr { color: #dc322f } /* Generic.Error */
# body .gh { color: #839496; font-weight: bold } /* Generic.Heading */
# body .gi { color: #859900 } /* Generic.Inserted */
# body .go { color: #839496 } /* Generic.Output */
# body .gp { color: #268bd2; font-weight: bold } /* Generic.Prompt */
# body .gs { color: #839496; font-weight: bold } /* Generic.Strong */
# body .gu { color: #839496; text-decoration: underline } /* Generic.Subheading */
# body .gt { color: #268bd2 } /* Generic.Traceback */
# body .kc { color: #2aa198 } /* Keyword.Constant */
# body .kd { color: #2aa198 } /* Keyword.Declaration */
# body .kn { color: #cb4b16 } /* Keyword.Namespace */
# body .kp { color: #859900 } /* Keyword.Pseudo */
# body .kr { color: #859900 } /* Keyword.Reserved */
# body .kt { color: #b58900 } /* Keyword.Type */
# body .ld { color: #839496 } /* Literal.Date */
# body .m { color: #2aa198 } /* Literal.Number */
# body .s { color: #2aa198 } /* Literal.String */
# body .na { color: #839496 } /* Name.Attribute */
# body .nb { color: #268bd2 } /* Name.Builtin */
# body .nc { color: #268bd2 } /* Name.Class */
# body .no { color: #268bd2 } /* Name.Constant */
# body .nd { color: #268bd2 } /* Name.Decorator */
# body .ni { color: #268bd2 } /* Name.Entity */
# body .ne { color: #268bd2 } /* Name.Exception */
# body .nf { color: #268bd2 } /* Name.Function */
# body .nl { color: #268bd2 } /* Name.Label */
# body .nn { color: #268bd2 } /* Name.Namespace */
# body .nx { color: #839496 } /* Name.Other */
# body .py { color: #839496 } /* Name.Property */
# body .nt { color: #268bd2 } /* Name.Tag */
# body .nv { color: #268bd2 } /* Name.Variable */
# body .ow { color: #859900 } /* Operator.Word */
# body .pm { color: #839496 } /* Punctuation.Marker */
# body .w { color: #839496 } /* Text.Whitespace */
# body .mb { color: #2aa198 } /* Literal.Number.Bin */
# body .mf { color: #2aa198 } /* Literal.Number.Float */
# body .mh { color: #2aa198 } /* Literal.Number.Hex */
# body .mi { color: #2aa198 } /* Literal.Number.Integer */
# body .mo { color: #2aa198 } /* Literal.Number.Oct */
# body .sa { color: #2aa198 } /* Literal.String.Affix */
# body .sb { color: #2aa198 } /* Literal.String.Backtick */
# body .sc { color: #2aa198 } /* Literal.String.Char */
# body .dl { color: #2aa198 } /* Literal.String.Delimiter */
# body .sd { color: #586e75 } /* Literal.String.Doc */
# body .s2 { color: #2aa198 } /* Literal.String.Double */
# body .se { color: #2aa198 } /* Literal.String.Escape */
# body .sh { color: #2aa198 } /* Literal.String.Heredoc */
# body .si { color: #2aa198 } /* Literal.String.Interpol */
# body .sx { color: #2aa198 } /* Literal.String.Other */
# body .sr { color: #cb4b16 } /* Literal.String.Regex */
# body .s1 { color: #2aa198 } /* Literal.String.Single */
# body .ss { color: #2aa198 } /* Literal.String.Symbol */
# body .bp { color: #268bd2 } /* Name.Builtin.Pseudo */
# body .fm { color: #268bd2 } /* Name.Function.Magic */
# body .vc { color: #268bd2 } /* Name.Variable.Class */
# body .vg { color: #268bd2 } /* Name.Variable.Global */
# body .vi { color: #268bd2 } /* Name.Variable.Instance */
# body .vm { color: #268bd2 } /* Name.Variable.Magic */
# body .il { color: #2aa198 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">SELECT</span> <span class="p">(</span><span class="nf">COUNT</span><span class="p">(</span><span class="k">DISTINCT</span> <span class="nv">?company</span><span class="p">)</span> <span class="k">AS</span> <span class="nv">?totalDistinctCompanies</span><span class="p">)</span>
# <span class="k">WHERE</span> <span class="p">{</span>
#   <span class="nv">?company</span> <span class="k">a</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">Company</span> <span class="p">.</span>
# <span class="p">}</span>
# </pre></div>
# </body>
# </html>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>totalDistinctCompanies</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1466</td>
#     </tr>
#   </tbody>
# </table>

# %%
run_query(g, '../queries/validation/address.rq')
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #073642 }
# body .c { color: #586e75; font-style: italic } /* Comment */
# body .err { color: #839496; background-color: #dc322f } /* Error */
# body .esc { color: #839496 } /* Escape */
# body .g { color: #839496 } /* Generic */
# body .k { color: #859900 } /* Keyword */
# body .l { color: #839496 } /* Literal */
# body .n { color: #839496 } /* Name */
# body .o { color: #586e75 } /* Operator */
# body .x { color: #839496 } /* Other */
# body .p { color: #839496 } /* Punctuation */
# body .ch { color: #586e75; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #586e75; font-style: italic } /* Comment.Multiline */
# body .cp { color: #d33682 } /* Comment.Preproc */
# body .cpf { color: #586e75 } /* Comment.PreprocFile */
# body .c1 { color: #586e75; font-style: italic } /* Comment.Single */
# body .cs { color: #586e75; font-style: italic } /* Comment.Special */
# body .gd { color: #dc322f } /* Generic.Deleted */
# body .ge { color: #839496; font-style: italic } /* Generic.Emph */
# body .ges { color: #839496; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# body .gr { color: #dc322f } /* Generic.Error */
# body .gh { color: #839496; font-weight: bold } /* Generic.Heading */
# body .gi { color: #859900 } /* Generic.Inserted */
# body .go { color: #839496 } /* Generic.Output */
# body .gp { color: #268bd2; font-weight: bold } /* Generic.Prompt */
# body .gs { color: #839496; font-weight: bold } /* Generic.Strong */
# body .gu { color: #839496; text-decoration: underline } /* Generic.Subheading */
# body .gt { color: #268bd2 } /* Generic.Traceback */
# body .kc { color: #2aa198 } /* Keyword.Constant */
# body .kd { color: #2aa198 } /* Keyword.Declaration */
# body .kn { color: #cb4b16 } /* Keyword.Namespace */
# body .kp { color: #859900 } /* Keyword.Pseudo */
# body .kr { color: #859900 } /* Keyword.Reserved */
# body .kt { color: #b58900 } /* Keyword.Type */
# body .ld { color: #839496 } /* Literal.Date */
# body .m { color: #2aa198 } /* Literal.Number */
# body .s { color: #2aa198 } /* Literal.String */
# body .na { color: #839496 } /* Name.Attribute */
# body .nb { color: #268bd2 } /* Name.Builtin */
# body .nc { color: #268bd2 } /* Name.Class */
# body .no { color: #268bd2 } /* Name.Constant */
# body .nd { color: #268bd2 } /* Name.Decorator */
# body .ni { color: #268bd2 } /* Name.Entity */
# body .ne { color: #268bd2 } /* Name.Exception */
# body .nf { color: #268bd2 } /* Name.Function */
# body .nl { color: #268bd2 } /* Name.Label */
# body .nn { color: #268bd2 } /* Name.Namespace */
# body .nx { color: #839496 } /* Name.Other */
# body .py { color: #839496 } /* Name.Property */
# body .nt { color: #268bd2 } /* Name.Tag */
# body .nv { color: #268bd2 } /* Name.Variable */
# body .ow { color: #859900 } /* Operator.Word */
# body .pm { color: #839496 } /* Punctuation.Marker */
# body .w { color: #839496 } /* Text.Whitespace */
# body .mb { color: #2aa198 } /* Literal.Number.Bin */
# body .mf { color: #2aa198 } /* Literal.Number.Float */
# body .mh { color: #2aa198 } /* Literal.Number.Hex */
# body .mi { color: #2aa198 } /* Literal.Number.Integer */
# body .mo { color: #2aa198 } /* Literal.Number.Oct */
# body .sa { color: #2aa198 } /* Literal.String.Affix */
# body .sb { color: #2aa198 } /* Literal.String.Backtick */
# body .sc { color: #2aa198 } /* Literal.String.Char */
# body .dl { color: #2aa198 } /* Literal.String.Delimiter */
# body .sd { color: #586e75 } /* Literal.String.Doc */
# body .s2 { color: #2aa198 } /* Literal.String.Double */
# body .se { color: #2aa198 } /* Literal.String.Escape */
# body .sh { color: #2aa198 } /* Literal.String.Heredoc */
# body .si { color: #2aa198 } /* Literal.String.Interpol */
# body .sx { color: #2aa198 } /* Literal.String.Other */
# body .sr { color: #cb4b16 } /* Literal.String.Regex */
# body .s1 { color: #2aa198 } /* Literal.String.Single */
# body .ss { color: #2aa198 } /* Literal.String.Symbol */
# body .bp { color: #268bd2 } /* Name.Builtin.Pseudo */
# body .fm { color: #268bd2 } /* Name.Function.Magic */
# body .vc { color: #268bd2 } /* Name.Variable.Class */
# body .vg { color: #268bd2 } /* Name.Variable.Global */
# body .vi { color: #268bd2 } /* Name.Variable.Instance */
# body .vm { color: #268bd2 } /* Name.Variable.Magic */
# body .il { color: #2aa198 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">SELECT</span>
#     <span class="p">(</span><span class="nf">COUNT</span><span class="p">(</span><span class="k">DISTINCT</span> <span class="nv">?company</span><span class="p">)</span> <span class="k">AS</span> <span class="nv">?totalCompanies</span><span class="p">)</span>
#     <span class="p">(</span><span class="nf">COUNT</span><span class="p">(</span><span class="k">DISTINCT</span> <span class="nv">?companyWithAddress</span><span class="p">)</span> <span class="k">AS</span> <span class="nv">?companyWithAddress</span><span class="p">)</span>
# <span class="k">WHERE</span> <span class="p">{</span>
#     <span class="p">{</span>
#         <span class="k">SELECT</span> <span class="k">DISTINCT</span> <span class="nv">?company</span>
#         <span class="k">WHERE</span> <span class="p">{</span>
#             <span class="nv">?company</span> <span class="k">a</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">Company</span> <span class="p">.</span>
#         <span class="p">}</span>
#     <span class="p">}</span>
#     <span class="k">OPTIONAL</span> <span class="p">{</span>
#         <span class="nv">?companyWithAddress</span> <span class="k">a</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">Company</span> <span class="p">;</span>
#             <span class="nn">finance</span><span class="p">:</span><span class="nt">hasAddress</span> <span class="nv">?address</span> <span class="p">.</span>
#     <span class="p">}</span>
# <span class="p">}</span>
# </pre></div>
# </body>
# </html>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>totalCompanies</th>
#       <th>companyWithAddress</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1466</td>
#       <td>1466</td>
#     </tr>
#   </tbody>
# </table>

# %%
run_query(g, '../queries/validation/recommendation.rq')
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #073642 }
# body .c { color: #586e75; font-style: italic } /* Comment */
# body .err { color: #839496; background-color: #dc322f } /* Error */
# body .esc { color: #839496 } /* Escape */
# body .g { color: #839496 } /* Generic */
# body .k { color: #859900 } /* Keyword */
# body .l { color: #839496 } /* Literal */
# body .n { color: #839496 } /* Name */
# body .o { color: #586e75 } /* Operator */
# body .x { color: #839496 } /* Other */
# body .p { color: #839496 } /* Punctuation */
# body .ch { color: #586e75; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #586e75; font-style: italic } /* Comment.Multiline */
# body .cp { color: #d33682 } /* Comment.Preproc */
# body .cpf { color: #586e75 } /* Comment.PreprocFile */
# body .c1 { color: #586e75; font-style: italic } /* Comment.Single */
# body .cs { color: #586e75; font-style: italic } /* Comment.Special */
# body .gd { color: #dc322f } /* Generic.Deleted */
# body .ge { color: #839496; font-style: italic } /* Generic.Emph */
# body .ges { color: #839496; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# body .gr { color: #dc322f } /* Generic.Error */
# body .gh { color: #839496; font-weight: bold } /* Generic.Heading */
# body .gi { color: #859900 } /* Generic.Inserted */
# body .go { color: #839496 } /* Generic.Output */
# body .gp { color: #268bd2; font-weight: bold } /* Generic.Prompt */
# body .gs { color: #839496; font-weight: bold } /* Generic.Strong */
# body .gu { color: #839496; text-decoration: underline } /* Generic.Subheading */
# body .gt { color: #268bd2 } /* Generic.Traceback */
# body .kc { color: #2aa198 } /* Keyword.Constant */
# body .kd { color: #2aa198 } /* Keyword.Declaration */
# body .kn { color: #cb4b16 } /* Keyword.Namespace */
# body .kp { color: #859900 } /* Keyword.Pseudo */
# body .kr { color: #859900 } /* Keyword.Reserved */
# body .kt { color: #b58900 } /* Keyword.Type */
# body .ld { color: #839496 } /* Literal.Date */
# body .m { color: #2aa198 } /* Literal.Number */
# body .s { color: #2aa198 } /* Literal.String */
# body .na { color: #839496 } /* Name.Attribute */
# body .nb { color: #268bd2 } /* Name.Builtin */
# body .nc { color: #268bd2 } /* Name.Class */
# body .no { color: #268bd2 } /* Name.Constant */
# body .nd { color: #268bd2 } /* Name.Decorator */
# body .ni { color: #268bd2 } /* Name.Entity */
# body .ne { color: #268bd2 } /* Name.Exception */
# body .nf { color: #268bd2 } /* Name.Function */
# body .nl { color: #268bd2 } /* Name.Label */
# body .nn { color: #268bd2 } /* Name.Namespace */
# body .nx { color: #839496 } /* Name.Other */
# body .py { color: #839496 } /* Name.Property */
# body .nt { color: #268bd2 } /* Name.Tag */
# body .nv { color: #268bd2 } /* Name.Variable */
# body .ow { color: #859900 } /* Operator.Word */
# body .pm { color: #839496 } /* Punctuation.Marker */
# body .w { color: #839496 } /* Text.Whitespace */
# body .mb { color: #2aa198 } /* Literal.Number.Bin */
# body .mf { color: #2aa198 } /* Literal.Number.Float */
# body .mh { color: #2aa198 } /* Literal.Number.Hex */
# body .mi { color: #2aa198 } /* Literal.Number.Integer */
# body .mo { color: #2aa198 } /* Literal.Number.Oct */
# body .sa { color: #2aa198 } /* Literal.String.Affix */
# body .sb { color: #2aa198 } /* Literal.String.Backtick */
# body .sc { color: #2aa198 } /* Literal.String.Char */
# body .dl { color: #2aa198 } /* Literal.String.Delimiter */
# body .sd { color: #586e75 } /* Literal.String.Doc */
# body .s2 { color: #2aa198 } /* Literal.String.Double */
# body .se { color: #2aa198 } /* Literal.String.Escape */
# body .sh { color: #2aa198 } /* Literal.String.Heredoc */
# body .si { color: #2aa198 } /* Literal.String.Interpol */
# body .sx { color: #2aa198 } /* Literal.String.Other */
# body .sr { color: #cb4b16 } /* Literal.String.Regex */
# body .s1 { color: #2aa198 } /* Literal.String.Single */
# body .ss { color: #2aa198 } /* Literal.String.Symbol */
# body .bp { color: #268bd2 } /* Name.Builtin.Pseudo */
# body .fm { color: #268bd2 } /* Name.Function.Magic */
# body .vc { color: #268bd2 } /* Name.Variable.Class */
# body .vg { color: #268bd2 } /* Name.Variable.Global */
# body .vi { color: #268bd2 } /* Name.Variable.Instance */
# body .vm { color: #268bd2 } /* Name.Variable.Magic */
# body .il { color: #2aa198 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">SELECT</span>
#     <span class="p">(</span><span class="nf">COUNT</span><span class="p">(</span><span class="k">DISTINCT</span> <span class="nv">?company</span><span class="p">)</span> <span class="k">AS</span> <span class="nv">?totalCompanies</span><span class="p">)</span>
#     <span class="p">(</span><span class="nf">COUNT</span><span class="p">(</span><span class="k">DISTINCT</span> <span class="nv">?companyWithRecommendation</span><span class="p">)</span> <span class="k">AS</span> <span class="nv">?companiesWithRecommendation</span><span class="p">)</span>
# <span class="k">WHERE</span> <span class="p">{</span>
#     <span class="p">{</span>
#         <span class="k">SELECT</span> <span class="k">DISTINCT</span> <span class="nv">?company</span>
#         <span class="k">WHERE</span> <span class="p">{</span>
#             <span class="nv">?company</span> <span class="k">a</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">Company</span> <span class="p">.</span>
#         <span class="p">}</span>
#     <span class="p">}</span>
#     <span class="k">OPTIONAL</span> <span class="p">{</span>
#         <span class="nv">?companyWithRecommendation</span> <span class="k">a</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">Company</span> <span class="p">;</span>
#             <span class="nn">finance</span><span class="p">:</span><span class="nt">hasRecommendation</span> <span class="nv">?recommendation</span> <span class="p">.</span>
#     <span class="p">}</span>
# <span class="p">}</span>
# </pre></div>
# </body>
# </html>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>totalCompanies</th>
#       <th>companiesWithRecommendation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1466</td>
#       <td>836</td>
#     </tr>
#   </tbody>
# </table>

# %%
run_query(g, '../queries/validation/earnings.rq')
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #073642 }
# body .c { color: #586e75; font-style: italic } /* Comment */
# body .err { color: #839496; background-color: #dc322f } /* Error */
# body .esc { color: #839496 } /* Escape */
# body .g { color: #839496 } /* Generic */
# body .k { color: #859900 } /* Keyword */
# body .l { color: #839496 } /* Literal */
# body .n { color: #839496 } /* Name */
# body .o { color: #586e75 } /* Operator */
# body .x { color: #839496 } /* Other */
# body .p { color: #839496 } /* Punctuation */
# body .ch { color: #586e75; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #586e75; font-style: italic } /* Comment.Multiline */
# body .cp { color: #d33682 } /* Comment.Preproc */
# body .cpf { color: #586e75 } /* Comment.PreprocFile */
# body .c1 { color: #586e75; font-style: italic } /* Comment.Single */
# body .cs { color: #586e75; font-style: italic } /* Comment.Special */
# body .gd { color: #dc322f } /* Generic.Deleted */
# body .ge { color: #839496; font-style: italic } /* Generic.Emph */
# body .ges { color: #839496; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# body .gr { color: #dc322f } /* Generic.Error */
# body .gh { color: #839496; font-weight: bold } /* Generic.Heading */
# body .gi { color: #859900 } /* Generic.Inserted */
# body .go { color: #839496 } /* Generic.Output */
# body .gp { color: #268bd2; font-weight: bold } /* Generic.Prompt */
# body .gs { color: #839496; font-weight: bold } /* Generic.Strong */
# body .gu { color: #839496; text-decoration: underline } /* Generic.Subheading */
# body .gt { color: #268bd2 } /* Generic.Traceback */
# body .kc { color: #2aa198 } /* Keyword.Constant */
# body .kd { color: #2aa198 } /* Keyword.Declaration */
# body .kn { color: #cb4b16 } /* Keyword.Namespace */
# body .kp { color: #859900 } /* Keyword.Pseudo */
# body .kr { color: #859900 } /* Keyword.Reserved */
# body .kt { color: #b58900 } /* Keyword.Type */
# body .ld { color: #839496 } /* Literal.Date */
# body .m { color: #2aa198 } /* Literal.Number */
# body .s { color: #2aa198 } /* Literal.String */
# body .na { color: #839496 } /* Name.Attribute */
# body .nb { color: #268bd2 } /* Name.Builtin */
# body .nc { color: #268bd2 } /* Name.Class */
# body .no { color: #268bd2 } /* Name.Constant */
# body .nd { color: #268bd2 } /* Name.Decorator */
# body .ni { color: #268bd2 } /* Name.Entity */
# body .ne { color: #268bd2 } /* Name.Exception */
# body .nf { color: #268bd2 } /* Name.Function */
# body .nl { color: #268bd2 } /* Name.Label */
# body .nn { color: #268bd2 } /* Name.Namespace */
# body .nx { color: #839496 } /* Name.Other */
# body .py { color: #839496 } /* Name.Property */
# body .nt { color: #268bd2 } /* Name.Tag */
# body .nv { color: #268bd2 } /* Name.Variable */
# body .ow { color: #859900 } /* Operator.Word */
# body .pm { color: #839496 } /* Punctuation.Marker */
# body .w { color: #839496 } /* Text.Whitespace */
# body .mb { color: #2aa198 } /* Literal.Number.Bin */
# body .mf { color: #2aa198 } /* Literal.Number.Float */
# body .mh { color: #2aa198 } /* Literal.Number.Hex */
# body .mi { color: #2aa198 } /* Literal.Number.Integer */
# body .mo { color: #2aa198 } /* Literal.Number.Oct */
# body .sa { color: #2aa198 } /* Literal.String.Affix */
# body .sb { color: #2aa198 } /* Literal.String.Backtick */
# body .sc { color: #2aa198 } /* Literal.String.Char */
# body .dl { color: #2aa198 } /* Literal.String.Delimiter */
# body .sd { color: #586e75 } /* Literal.String.Doc */
# body .s2 { color: #2aa198 } /* Literal.String.Double */
# body .se { color: #2aa198 } /* Literal.String.Escape */
# body .sh { color: #2aa198 } /* Literal.String.Heredoc */
# body .si { color: #2aa198 } /* Literal.String.Interpol */
# body .sx { color: #2aa198 } /* Literal.String.Other */
# body .sr { color: #cb4b16 } /* Literal.String.Regex */
# body .s1 { color: #2aa198 } /* Literal.String.Single */
# body .ss { color: #2aa198 } /* Literal.String.Symbol */
# body .bp { color: #268bd2 } /* Name.Builtin.Pseudo */
# body .fm { color: #268bd2 } /* Name.Function.Magic */
# body .vc { color: #268bd2 } /* Name.Variable.Class */
# body .vg { color: #268bd2 } /* Name.Variable.Global */
# body .vi { color: #268bd2 } /* Name.Variable.Instance */
# body .vm { color: #268bd2 } /* Name.Variable.Magic */
# body .il { color: #2aa198 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">SELECT</span>
#     <span class="p">(</span><span class="nf">COUNT</span><span class="p">(</span><span class="k">DISTINCT</span> <span class="nv">?company</span><span class="p">)</span> <span class="k">AS</span> <span class="nv">?totalCompanies</span><span class="p">)</span>
#     <span class="p">(</span><span class="nf">COUNT</span><span class="p">(</span><span class="k">DISTINCT</span> <span class="nv">?companyWithEarningsDate</span><span class="p">)</span> <span class="k">AS</span> <span class="nv">?companiesWithEarningsDate</span><span class="p">)</span>
# <span class="k">WHERE</span> <span class="p">{</span>
#     <span class="p">{</span>
#         <span class="k">SELECT</span> <span class="k">DISTINCT</span> <span class="nv">?company</span>
#         <span class="k">WHERE</span> <span class="p">{</span>
#             <span class="nv">?company</span> <span class="k">a</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">Company</span> <span class="p">.</span>
#         <span class="p">}</span>
#     <span class="p">}</span>
#     <span class="k">OPTIONAL</span> <span class="p">{</span>
#         <span class="nv">?companyWithEarningsDate</span> <span class="k">a</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">Company</span> <span class="p">;</span>
#             <span class="nn">finance</span><span class="p">:</span><span class="nt">hasEarningsDate</span> <span class="nv">?earningsDate</span> <span class="p">.</span>
#     <span class="p">}</span>
# <span class="p">}</span>
# </pre></div>
# </body>
# </html>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>totalCompanies</th>
#       <th>companiesWithEarningsDate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1466</td>
#       <td>1249</td>
#     </tr>
#   </tbody>
# </table>

# %%
run_query(g, '../queries/validation/industry.rq')
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #073642 }
# body .c { color: #586e75; font-style: italic } /* Comment */
# body .err { color: #839496; background-color: #dc322f } /* Error */
# body .esc { color: #839496 } /* Escape */
# body .g { color: #839496 } /* Generic */
# body .k { color: #859900 } /* Keyword */
# body .l { color: #839496 } /* Literal */
# body .n { color: #839496 } /* Name */
# body .o { color: #586e75 } /* Operator */
# body .x { color: #839496 } /* Other */
# body .p { color: #839496 } /* Punctuation */
# body .ch { color: #586e75; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #586e75; font-style: italic } /* Comment.Multiline */
# body .cp { color: #d33682 } /* Comment.Preproc */
# body .cpf { color: #586e75 } /* Comment.PreprocFile */
# body .c1 { color: #586e75; font-style: italic } /* Comment.Single */
# body .cs { color: #586e75; font-style: italic } /* Comment.Special */
# body .gd { color: #dc322f } /* Generic.Deleted */
# body .ge { color: #839496; font-style: italic } /* Generic.Emph */
# body .ges { color: #839496; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# body .gr { color: #dc322f } /* Generic.Error */
# body .gh { color: #839496; font-weight: bold } /* Generic.Heading */
# body .gi { color: #859900 } /* Generic.Inserted */
# body .go { color: #839496 } /* Generic.Output */
# body .gp { color: #268bd2; font-weight: bold } /* Generic.Prompt */
# body .gs { color: #839496; font-weight: bold } /* Generic.Strong */
# body .gu { color: #839496; text-decoration: underline } /* Generic.Subheading */
# body .gt { color: #268bd2 } /* Generic.Traceback */
# body .kc { color: #2aa198 } /* Keyword.Constant */
# body .kd { color: #2aa198 } /* Keyword.Declaration */
# body .kn { color: #cb4b16 } /* Keyword.Namespace */
# body .kp { color: #859900 } /* Keyword.Pseudo */
# body .kr { color: #859900 } /* Keyword.Reserved */
# body .kt { color: #b58900 } /* Keyword.Type */
# body .ld { color: #839496 } /* Literal.Date */
# body .m { color: #2aa198 } /* Literal.Number */
# body .s { color: #2aa198 } /* Literal.String */
# body .na { color: #839496 } /* Name.Attribute */
# body .nb { color: #268bd2 } /* Name.Builtin */
# body .nc { color: #268bd2 } /* Name.Class */
# body .no { color: #268bd2 } /* Name.Constant */
# body .nd { color: #268bd2 } /* Name.Decorator */
# body .ni { color: #268bd2 } /* Name.Entity */
# body .ne { color: #268bd2 } /* Name.Exception */
# body .nf { color: #268bd2 } /* Name.Function */
# body .nl { color: #268bd2 } /* Name.Label */
# body .nn { color: #268bd2 } /* Name.Namespace */
# body .nx { color: #839496 } /* Name.Other */
# body .py { color: #839496 } /* Name.Property */
# body .nt { color: #268bd2 } /* Name.Tag */
# body .nv { color: #268bd2 } /* Name.Variable */
# body .ow { color: #859900 } /* Operator.Word */
# body .pm { color: #839496 } /* Punctuation.Marker */
# body .w { color: #839496 } /* Text.Whitespace */
# body .mb { color: #2aa198 } /* Literal.Number.Bin */
# body .mf { color: #2aa198 } /* Literal.Number.Float */
# body .mh { color: #2aa198 } /* Literal.Number.Hex */
# body .mi { color: #2aa198 } /* Literal.Number.Integer */
# body .mo { color: #2aa198 } /* Literal.Number.Oct */
# body .sa { color: #2aa198 } /* Literal.String.Affix */
# body .sb { color: #2aa198 } /* Literal.String.Backtick */
# body .sc { color: #2aa198 } /* Literal.String.Char */
# body .dl { color: #2aa198 } /* Literal.String.Delimiter */
# body .sd { color: #586e75 } /* Literal.String.Doc */
# body .s2 { color: #2aa198 } /* Literal.String.Double */
# body .se { color: #2aa198 } /* Literal.String.Escape */
# body .sh { color: #2aa198 } /* Literal.String.Heredoc */
# body .si { color: #2aa198 } /* Literal.String.Interpol */
# body .sx { color: #2aa198 } /* Literal.String.Other */
# body .sr { color: #cb4b16 } /* Literal.String.Regex */
# body .s1 { color: #2aa198 } /* Literal.String.Single */
# body .ss { color: #2aa198 } /* Literal.String.Symbol */
# body .bp { color: #268bd2 } /* Name.Builtin.Pseudo */
# body .fm { color: #268bd2 } /* Name.Function.Magic */
# body .vc { color: #268bd2 } /* Name.Variable.Class */
# body .vg { color: #268bd2 } /* Name.Variable.Global */
# body .vi { color: #268bd2 } /* Name.Variable.Instance */
# body .vm { color: #268bd2 } /* Name.Variable.Magic */
# body .il { color: #2aa198 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">SELECT</span> <span class="k">DISTINCT</span> <span class="nv">?companyName</span> <span class="nv">?ticker</span>
# <span class="k">WHERE</span> <span class="p">{</span>
#   <span class="nv">?company</span> <span class="k">a</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">Company</span> <span class="p">;</span>
#            <span class="nn">finance</span><span class="p">:</span><span class="nt">hasName</span> <span class="nv">?companyName</span> <span class="p">;</span>
#            <span class="nn">finance</span><span class="p">:</span><span class="nt">hasTicker</span> <span class="nv">?ticker</span> <span class="p">.</span>
#   <span class="k">FILTER</span> <span class="nf">NOT EXISTS</span> <span class="p">{</span>
#     <span class="nv">?company</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">hasIndustry</span> <span class="nv">?industry</span> <span class="p">.</span>
#   <span class="p">}</span>
# <span class="p">}</span>
# </pre></div>
# </body>
# </html>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>companyName</th>
#       <th>ticker</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>LIFCO AB</td>
#       <td>LFABF</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>MICHELIN(CIE GLE DES ETABL.)</td>
#       <td>MGDDF</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>ISRAEL DISCOUNT BANK</td>
#       <td>ISDAF</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>AMPLIFON</td>
#       <td>AMFPF</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>BANQUE CANTONALE VAUDOISE</td>
#       <td>BQCNF</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>3I GROUP</td>
#       <td>TGOPF</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>SYENSQO SA</td>
#       <td>SHBBF</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>HIKARI TSUSHIN INC</td>
#       <td>HKTGF</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Analysis queries

# %%
run_query(g, '../queries/companies_per_etf.rq')
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #073642 }
# body .c { color: #586e75; font-style: italic } /* Comment */
# body .err { color: #839496; background-color: #dc322f } /* Error */
# body .esc { color: #839496 } /* Escape */
# body .g { color: #839496 } /* Generic */
# body .k { color: #859900 } /* Keyword */
# body .l { color: #839496 } /* Literal */
# body .n { color: #839496 } /* Name */
# body .o { color: #586e75 } /* Operator */
# body .x { color: #839496 } /* Other */
# body .p { color: #839496 } /* Punctuation */
# body .ch { color: #586e75; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #586e75; font-style: italic } /* Comment.Multiline */
# body .cp { color: #d33682 } /* Comment.Preproc */
# body .cpf { color: #586e75 } /* Comment.PreprocFile */
# body .c1 { color: #586e75; font-style: italic } /* Comment.Single */
# body .cs { color: #586e75; font-style: italic } /* Comment.Special */
# body .gd { color: #dc322f } /* Generic.Deleted */
# body .ge { color: #839496; font-style: italic } /* Generic.Emph */
# body .ges { color: #839496; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# body .gr { color: #dc322f } /* Generic.Error */
# body .gh { color: #839496; font-weight: bold } /* Generic.Heading */
# body .gi { color: #859900 } /* Generic.Inserted */
# body .go { color: #839496 } /* Generic.Output */
# body .gp { color: #268bd2; font-weight: bold } /* Generic.Prompt */
# body .gs { color: #839496; font-weight: bold } /* Generic.Strong */
# body .gu { color: #839496; text-decoration: underline } /* Generic.Subheading */
# body .gt { color: #268bd2 } /* Generic.Traceback */
# body .kc { color: #2aa198 } /* Keyword.Constant */
# body .kd { color: #2aa198 } /* Keyword.Declaration */
# body .kn { color: #cb4b16 } /* Keyword.Namespace */
# body .kp { color: #859900 } /* Keyword.Pseudo */
# body .kr { color: #859900 } /* Keyword.Reserved */
# body .kt { color: #b58900 } /* Keyword.Type */
# body .ld { color: #839496 } /* Literal.Date */
# body .m { color: #2aa198 } /* Literal.Number */
# body .s { color: #2aa198 } /* Literal.String */
# body .na { color: #839496 } /* Name.Attribute */
# body .nb { color: #268bd2 } /* Name.Builtin */
# body .nc { color: #268bd2 } /* Name.Class */
# body .no { color: #268bd2 } /* Name.Constant */
# body .nd { color: #268bd2 } /* Name.Decorator */
# body .ni { color: #268bd2 } /* Name.Entity */
# body .ne { color: #268bd2 } /* Name.Exception */
# body .nf { color: #268bd2 } /* Name.Function */
# body .nl { color: #268bd2 } /* Name.Label */
# body .nn { color: #268bd2 } /* Name.Namespace */
# body .nx { color: #839496 } /* Name.Other */
# body .py { color: #839496 } /* Name.Property */
# body .nt { color: #268bd2 } /* Name.Tag */
# body .nv { color: #268bd2 } /* Name.Variable */
# body .ow { color: #859900 } /* Operator.Word */
# body .pm { color: #839496 } /* Punctuation.Marker */
# body .w { color: #839496 } /* Text.Whitespace */
# body .mb { color: #2aa198 } /* Literal.Number.Bin */
# body .mf { color: #2aa198 } /* Literal.Number.Float */
# body .mh { color: #2aa198 } /* Literal.Number.Hex */
# body .mi { color: #2aa198 } /* Literal.Number.Integer */
# body .mo { color: #2aa198 } /* Literal.Number.Oct */
# body .sa { color: #2aa198 } /* Literal.String.Affix */
# body .sb { color: #2aa198 } /* Literal.String.Backtick */
# body .sc { color: #2aa198 } /* Literal.String.Char */
# body .dl { color: #2aa198 } /* Literal.String.Delimiter */
# body .sd { color: #586e75 } /* Literal.String.Doc */
# body .s2 { color: #2aa198 } /* Literal.String.Double */
# body .se { color: #2aa198 } /* Literal.String.Escape */
# body .sh { color: #2aa198 } /* Literal.String.Heredoc */
# body .si { color: #2aa198 } /* Literal.String.Interpol */
# body .sx { color: #2aa198 } /* Literal.String.Other */
# body .sr { color: #cb4b16 } /* Literal.String.Regex */
# body .s1 { color: #2aa198 } /* Literal.String.Single */
# body .ss { color: #2aa198 } /* Literal.String.Symbol */
# body .bp { color: #268bd2 } /* Name.Builtin.Pseudo */
# body .fm { color: #268bd2 } /* Name.Function.Magic */
# body .vc { color: #268bd2 } /* Name.Variable.Class */
# body .vg { color: #268bd2 } /* Name.Variable.Global */
# body .vi { color: #268bd2 } /* Name.Variable.Instance */
# body .vm { color: #268bd2 } /* Name.Variable.Magic */
# body .il { color: #2aa198 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">SELECT</span> <span class="nv">?etfname</span> <span class="p">(</span><span class="nf">COUNT</span><span class="p">(</span><span class="nv">?company</span><span class="p">)</span> <span class="k">AS</span> <span class="nv">?companyCount</span><span class="p">)</span> <span class="p">(</span><span class="nf">COUNT</span><span class="p">(</span><span class="nv">?companyName</span><span class="p">)</span> <span class="k">AS</span> <span class="nv">?companyNameCount</span><span class="p">)</span>
# <span class="k">WHERE</span> <span class="p">{</span>
#   <span class="nv">?etf</span> <span class="k">a</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">ETF</span> <span class="p">;</span>
#        <span class="nn">finance</span><span class="p">:</span><span class="nt">hasName</span> <span class="nv">?etfname</span> <span class="p">;</span>
#        <span class="nn">finance</span><span class="p">:</span><span class="nt">hasCompany</span> <span class="nv">?company</span> <span class="p">.</span>
#   <span class="nv">?company</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">hasName</span> <span class="nv">?companyName</span> <span class="p">.</span>
# <span class="p">}</span>
# <span class="k">GROUP BY</span> <span class="nv">?etfname</span>
# </pre></div>
# </body>
# </html>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>etfname</th>
#       <th>companyCount</th>
#       <th>companyNameCount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>iShares MSCI World ETF</td>
#       <td>1441</td>
#       <td>1441</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>iShares Core S&amp;P 500 ETF</td>
#       <td>502</td>
#       <td>502</td>
#     </tr>
#   </tbody>
# </table>

# %%
run_query(g, '../queries/gender.rq')
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #073642 }
# body .c { color: #586e75; font-style: italic } /* Comment */
# body .err { color: #839496; background-color: #dc322f } /* Error */
# body .esc { color: #839496 } /* Escape */
# body .g { color: #839496 } /* Generic */
# body .k { color: #859900 } /* Keyword */
# body .l { color: #839496 } /* Literal */
# body .n { color: #839496 } /* Name */
# body .o { color: #586e75 } /* Operator */
# body .x { color: #839496 } /* Other */
# body .p { color: #839496 } /* Punctuation */
# body .ch { color: #586e75; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #586e75; font-style: italic } /* Comment.Multiline */
# body .cp { color: #d33682 } /* Comment.Preproc */
# body .cpf { color: #586e75 } /* Comment.PreprocFile */
# body .c1 { color: #586e75; font-style: italic } /* Comment.Single */
# body .cs { color: #586e75; font-style: italic } /* Comment.Special */
# body .gd { color: #dc322f } /* Generic.Deleted */
# body .ge { color: #839496; font-style: italic } /* Generic.Emph */
# body .ges { color: #839496; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# body .gr { color: #dc322f } /* Generic.Error */
# body .gh { color: #839496; font-weight: bold } /* Generic.Heading */
# body .gi { color: #859900 } /* Generic.Inserted */
# body .go { color: #839496 } /* Generic.Output */
# body .gp { color: #268bd2; font-weight: bold } /* Generic.Prompt */
# body .gs { color: #839496; font-weight: bold } /* Generic.Strong */
# body .gu { color: #839496; text-decoration: underline } /* Generic.Subheading */
# body .gt { color: #268bd2 } /* Generic.Traceback */
# body .kc { color: #2aa198 } /* Keyword.Constant */
# body .kd { color: #2aa198 } /* Keyword.Declaration */
# body .kn { color: #cb4b16 } /* Keyword.Namespace */
# body .kp { color: #859900 } /* Keyword.Pseudo */
# body .kr { color: #859900 } /* Keyword.Reserved */
# body .kt { color: #b58900 } /* Keyword.Type */
# body .ld { color: #839496 } /* Literal.Date */
# body .m { color: #2aa198 } /* Literal.Number */
# body .s { color: #2aa198 } /* Literal.String */
# body .na { color: #839496 } /* Name.Attribute */
# body .nb { color: #268bd2 } /* Name.Builtin */
# body .nc { color: #268bd2 } /* Name.Class */
# body .no { color: #268bd2 } /* Name.Constant */
# body .nd { color: #268bd2 } /* Name.Decorator */
# body .ni { color: #268bd2 } /* Name.Entity */
# body .ne { color: #268bd2 } /* Name.Exception */
# body .nf { color: #268bd2 } /* Name.Function */
# body .nl { color: #268bd2 } /* Name.Label */
# body .nn { color: #268bd2 } /* Name.Namespace */
# body .nx { color: #839496 } /* Name.Other */
# body .py { color: #839496 } /* Name.Property */
# body .nt { color: #268bd2 } /* Name.Tag */
# body .nv { color: #268bd2 } /* Name.Variable */
# body .ow { color: #859900 } /* Operator.Word */
# body .pm { color: #839496 } /* Punctuation.Marker */
# body .w { color: #839496 } /* Text.Whitespace */
# body .mb { color: #2aa198 } /* Literal.Number.Bin */
# body .mf { color: #2aa198 } /* Literal.Number.Float */
# body .mh { color: #2aa198 } /* Literal.Number.Hex */
# body .mi { color: #2aa198 } /* Literal.Number.Integer */
# body .mo { color: #2aa198 } /* Literal.Number.Oct */
# body .sa { color: #2aa198 } /* Literal.String.Affix */
# body .sb { color: #2aa198 } /* Literal.String.Backtick */
# body .sc { color: #2aa198 } /* Literal.String.Char */
# body .dl { color: #2aa198 } /* Literal.String.Delimiter */
# body .sd { color: #586e75 } /* Literal.String.Doc */
# body .s2 { color: #2aa198 } /* Literal.String.Double */
# body .se { color: #2aa198 } /* Literal.String.Escape */
# body .sh { color: #2aa198 } /* Literal.String.Heredoc */
# body .si { color: #2aa198 } /* Literal.String.Interpol */
# body .sx { color: #2aa198 } /* Literal.String.Other */
# body .sr { color: #cb4b16 } /* Literal.String.Regex */
# body .s1 { color: #2aa198 } /* Literal.String.Single */
# body .ss { color: #2aa198 } /* Literal.String.Symbol */
# body .bp { color: #268bd2 } /* Name.Builtin.Pseudo */
# body .fm { color: #268bd2 } /* Name.Function.Magic */
# body .vc { color: #268bd2 } /* Name.Variable.Class */
# body .vg { color: #268bd2 } /* Name.Variable.Global */
# body .vi { color: #268bd2 } /* Name.Variable.Instance */
# body .vm { color: #268bd2 } /* Name.Variable.Magic */
# body .il { color: #2aa198 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">SELECT</span> <span class="nv">?gender</span> <span class="p">(</span><span class="nf">COUNT</span><span class="p">(</span><span class="nv">?person</span><span class="p">)</span> <span class="k">AS</span> <span class="nv">?count</span><span class="p">)</span>
# <span class="k">WHERE</span> <span class="p">{</span>
#   <span class="nv">?person</span> <span class="k">a</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">Person</span> <span class="p">.</span>
#   <span class="nv">?person</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">hasGender</span> <span class="nv">?gender</span> <span class="p">.</span>
# <span class="p">}</span>
# <span class="k">GROUP BY</span> <span class="nv">?gender</span>
# </pre></div>
# </body>
# </html>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>gender</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>w</td>
#       <td>2830</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>m</td>
#       <td>8924</td>
#     </tr>
#   </tbody>
# </table>

# %%
run_query(g, '../queries/sp_500_companies_not_in_msci.rq')
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #073642 }
# body .c { color: #586e75; font-style: italic } /* Comment */
# body .err { color: #839496; background-color: #dc322f } /* Error */
# body .esc { color: #839496 } /* Escape */
# body .g { color: #839496 } /* Generic */
# body .k { color: #859900 } /* Keyword */
# body .l { color: #839496 } /* Literal */
# body .n { color: #839496 } /* Name */
# body .o { color: #586e75 } /* Operator */
# body .x { color: #839496 } /* Other */
# body .p { color: #839496 } /* Punctuation */
# body .ch { color: #586e75; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #586e75; font-style: italic } /* Comment.Multiline */
# body .cp { color: #d33682 } /* Comment.Preproc */
# body .cpf { color: #586e75 } /* Comment.PreprocFile */
# body .c1 { color: #586e75; font-style: italic } /* Comment.Single */
# body .cs { color: #586e75; font-style: italic } /* Comment.Special */
# body .gd { color: #dc322f } /* Generic.Deleted */
# body .ge { color: #839496; font-style: italic } /* Generic.Emph */
# body .ges { color: #839496; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# body .gr { color: #dc322f } /* Generic.Error */
# body .gh { color: #839496; font-weight: bold } /* Generic.Heading */
# body .gi { color: #859900 } /* Generic.Inserted */
# body .go { color: #839496 } /* Generic.Output */
# body .gp { color: #268bd2; font-weight: bold } /* Generic.Prompt */
# body .gs { color: #839496; font-weight: bold } /* Generic.Strong */
# body .gu { color: #839496; text-decoration: underline } /* Generic.Subheading */
# body .gt { color: #268bd2 } /* Generic.Traceback */
# body .kc { color: #2aa198 } /* Keyword.Constant */
# body .kd { color: #2aa198 } /* Keyword.Declaration */
# body .kn { color: #cb4b16 } /* Keyword.Namespace */
# body .kp { color: #859900 } /* Keyword.Pseudo */
# body .kr { color: #859900 } /* Keyword.Reserved */
# body .kt { color: #b58900 } /* Keyword.Type */
# body .ld { color: #839496 } /* Literal.Date */
# body .m { color: #2aa198 } /* Literal.Number */
# body .s { color: #2aa198 } /* Literal.String */
# body .na { color: #839496 } /* Name.Attribute */
# body .nb { color: #268bd2 } /* Name.Builtin */
# body .nc { color: #268bd2 } /* Name.Class */
# body .no { color: #268bd2 } /* Name.Constant */
# body .nd { color: #268bd2 } /* Name.Decorator */
# body .ni { color: #268bd2 } /* Name.Entity */
# body .ne { color: #268bd2 } /* Name.Exception */
# body .nf { color: #268bd2 } /* Name.Function */
# body .nl { color: #268bd2 } /* Name.Label */
# body .nn { color: #268bd2 } /* Name.Namespace */
# body .nx { color: #839496 } /* Name.Other */
# body .py { color: #839496 } /* Name.Property */
# body .nt { color: #268bd2 } /* Name.Tag */
# body .nv { color: #268bd2 } /* Name.Variable */
# body .ow { color: #859900 } /* Operator.Word */
# body .pm { color: #839496 } /* Punctuation.Marker */
# body .w { color: #839496 } /* Text.Whitespace */
# body .mb { color: #2aa198 } /* Literal.Number.Bin */
# body .mf { color: #2aa198 } /* Literal.Number.Float */
# body .mh { color: #2aa198 } /* Literal.Number.Hex */
# body .mi { color: #2aa198 } /* Literal.Number.Integer */
# body .mo { color: #2aa198 } /* Literal.Number.Oct */
# body .sa { color: #2aa198 } /* Literal.String.Affix */
# body .sb { color: #2aa198 } /* Literal.String.Backtick */
# body .sc { color: #2aa198 } /* Literal.String.Char */
# body .dl { color: #2aa198 } /* Literal.String.Delimiter */
# body .sd { color: #586e75 } /* Literal.String.Doc */
# body .s2 { color: #2aa198 } /* Literal.String.Double */
# body .se { color: #2aa198 } /* Literal.String.Escape */
# body .sh { color: #2aa198 } /* Literal.String.Heredoc */
# body .si { color: #2aa198 } /* Literal.String.Interpol */
# body .sx { color: #2aa198 } /* Literal.String.Other */
# body .sr { color: #cb4b16 } /* Literal.String.Regex */
# body .s1 { color: #2aa198 } /* Literal.String.Single */
# body .ss { color: #2aa198 } /* Literal.String.Symbol */
# body .bp { color: #268bd2 } /* Name.Builtin.Pseudo */
# body .fm { color: #268bd2 } /* Name.Function.Magic */
# body .vc { color: #268bd2 } /* Name.Variable.Class */
# body .vg { color: #268bd2 } /* Name.Variable.Global */
# body .vi { color: #268bd2 } /* Name.Variable.Instance */
# body .vm { color: #268bd2 } /* Name.Variable.Magic */
# body .il { color: #2aa198 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">SELECT</span> <span class="nv">?companyName</span> <span class="nv">?companyTicker</span>
# <span class="k">WHERE</span> <span class="p">{</span>
#   <span class="nv">?ivvEtf</span> <span class="nn">rdf</span><span class="p">:</span><span class="nt">type</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">ETF</span> <span class="p">;</span>
#           <span class="nn">finance</span><span class="p">:</span><span class="nt">hasTicker</span> <span class="s">&quot;IVV&quot;</span> <span class="p">;</span>
#           <span class="nn">finance</span><span class="p">:</span><span class="nt">hasCompany</span> <span class="nv">?company</span> <span class="p">.</span>
#
#   <span class="k">FILTER</span> <span class="nf">NOT EXISTS</span> <span class="p">{</span>
#     <span class="nv">?urthEtf</span> <span class="nn">rdf</span><span class="p">:</span><span class="nt">type</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">ETF</span> <span class="p">;</span>
#              <span class="nn">finance</span><span class="p">:</span><span class="nt">hasTicker</span> <span class="s">&quot;URTH&quot;</span> <span class="p">;</span>
#              <span class="nn">finance</span><span class="p">:</span><span class="nt">hasCompany</span> <span class="nv">?company</span> <span class="p">.</span>
#   <span class="p">}</span>
#
#   <span class="nv">?company</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">hasName</span> <span class="nv">?companyName</span> <span class="p">;</span>
#            <span class="nn">finance</span><span class="p">:</span><span class="nt">hasTicker</span> <span class="nv">?companyTicker</span> <span class="p">.</span>
# <span class="p">}</span>
# </pre></div>
# </body>
# </html>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>companyName</th>
#       <th>companyTicker</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Tapestry, Inc.</td>
#       <td>TPR</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>V.F. Corporation</td>
#       <td>VFC</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Palo Alto Networks, Inc.</td>
#       <td>PANW</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Mondelez International, Inc.</td>
#       <td>MDLZ</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Invesco Ltd</td>
#       <td>IVZ</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Pinnacle West Capital Corporati</td>
#       <td>PNW</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Walt Disney Company (The)</td>
#       <td>DIS</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>United Parcel Service, Inc.</td>
#       <td>UPS</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Ralph Lauren Corporation</td>
#       <td>RL</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Whirlpool Corporation</td>
#       <td>WHR</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>The Bank of New York Mellon Cor</td>
#       <td>BK</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Generac Holdlings Inc.</td>
#       <td>GNRC</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Goldman Sachs Group, Inc. (The)</td>
#       <td>GS</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Mohawk Industries, Inc.</td>
#       <td>MHK</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Federal Realty Investment Trust</td>
#       <td>FRT</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Blackstone Inc.</td>
#       <td>BX</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>AbbVie Inc.</td>
#       <td>ABBV</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Evergy, Inc.</td>
#       <td>EVRG</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>United Airlines Holdings, Inc.</td>
#       <td>UAL</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Vertex Pharmaceuticals Incorpor</td>
#       <td>VRTX</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>Zions Bancorporation N.A.</td>
#       <td>ZION</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>Comerica Incorporated</td>
#       <td>CMA</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>DENTSPLY SIRONA Inc.</td>
#       <td>XRAY</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>American Airlines Group, Inc.</td>
#       <td>AAL</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>News Corporation</td>
#       <td>NWS</td>
#     </tr>
#   </tbody>
# </table>

# %%
run_query(g, '../queries/msci_companies_not_in_sp_500.rq')
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #073642 }
# body .c { color: #586e75; font-style: italic } /* Comment */
# body .err { color: #839496; background-color: #dc322f } /* Error */
# body .esc { color: #839496 } /* Escape */
# body .g { color: #839496 } /* Generic */
# body .k { color: #859900 } /* Keyword */
# body .l { color: #839496 } /* Literal */
# body .n { color: #839496 } /* Name */
# body .o { color: #586e75 } /* Operator */
# body .x { color: #839496 } /* Other */
# body .p { color: #839496 } /* Punctuation */
# body .ch { color: #586e75; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #586e75; font-style: italic } /* Comment.Multiline */
# body .cp { color: #d33682 } /* Comment.Preproc */
# body .cpf { color: #586e75 } /* Comment.PreprocFile */
# body .c1 { color: #586e75; font-style: italic } /* Comment.Single */
# body .cs { color: #586e75; font-style: italic } /* Comment.Special */
# body .gd { color: #dc322f } /* Generic.Deleted */
# body .ge { color: #839496; font-style: italic } /* Generic.Emph */
# body .ges { color: #839496; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# body .gr { color: #dc322f } /* Generic.Error */
# body .gh { color: #839496; font-weight: bold } /* Generic.Heading */
# body .gi { color: #859900 } /* Generic.Inserted */
# body .go { color: #839496 } /* Generic.Output */
# body .gp { color: #268bd2; font-weight: bold } /* Generic.Prompt */
# body .gs { color: #839496; font-weight: bold } /* Generic.Strong */
# body .gu { color: #839496; text-decoration: underline } /* Generic.Subheading */
# body .gt { color: #268bd2 } /* Generic.Traceback */
# body .kc { color: #2aa198 } /* Keyword.Constant */
# body .kd { color: #2aa198 } /* Keyword.Declaration */
# body .kn { color: #cb4b16 } /* Keyword.Namespace */
# body .kp { color: #859900 } /* Keyword.Pseudo */
# body .kr { color: #859900 } /* Keyword.Reserved */
# body .kt { color: #b58900 } /* Keyword.Type */
# body .ld { color: #839496 } /* Literal.Date */
# body .m { color: #2aa198 } /* Literal.Number */
# body .s { color: #2aa198 } /* Literal.String */
# body .na { color: #839496 } /* Name.Attribute */
# body .nb { color: #268bd2 } /* Name.Builtin */
# body .nc { color: #268bd2 } /* Name.Class */
# body .no { color: #268bd2 } /* Name.Constant */
# body .nd { color: #268bd2 } /* Name.Decorator */
# body .ni { color: #268bd2 } /* Name.Entity */
# body .ne { color: #268bd2 } /* Name.Exception */
# body .nf { color: #268bd2 } /* Name.Function */
# body .nl { color: #268bd2 } /* Name.Label */
# body .nn { color: #268bd2 } /* Name.Namespace */
# body .nx { color: #839496 } /* Name.Other */
# body .py { color: #839496 } /* Name.Property */
# body .nt { color: #268bd2 } /* Name.Tag */
# body .nv { color: #268bd2 } /* Name.Variable */
# body .ow { color: #859900 } /* Operator.Word */
# body .pm { color: #839496 } /* Punctuation.Marker */
# body .w { color: #839496 } /* Text.Whitespace */
# body .mb { color: #2aa198 } /* Literal.Number.Bin */
# body .mf { color: #2aa198 } /* Literal.Number.Float */
# body .mh { color: #2aa198 } /* Literal.Number.Hex */
# body .mi { color: #2aa198 } /* Literal.Number.Integer */
# body .mo { color: #2aa198 } /* Literal.Number.Oct */
# body .sa { color: #2aa198 } /* Literal.String.Affix */
# body .sb { color: #2aa198 } /* Literal.String.Backtick */
# body .sc { color: #2aa198 } /* Literal.String.Char */
# body .dl { color: #2aa198 } /* Literal.String.Delimiter */
# body .sd { color: #586e75 } /* Literal.String.Doc */
# body .s2 { color: #2aa198 } /* Literal.String.Double */
# body .se { color: #2aa198 } /* Literal.String.Escape */
# body .sh { color: #2aa198 } /* Literal.String.Heredoc */
# body .si { color: #2aa198 } /* Literal.String.Interpol */
# body .sx { color: #2aa198 } /* Literal.String.Other */
# body .sr { color: #cb4b16 } /* Literal.String.Regex */
# body .s1 { color: #2aa198 } /* Literal.String.Single */
# body .ss { color: #2aa198 } /* Literal.String.Symbol */
# body .bp { color: #268bd2 } /* Name.Builtin.Pseudo */
# body .fm { color: #268bd2 } /* Name.Function.Magic */
# body .vc { color: #268bd2 } /* Name.Variable.Class */
# body .vg { color: #268bd2 } /* Name.Variable.Global */
# body .vi { color: #268bd2 } /* Name.Variable.Instance */
# body .vm { color: #268bd2 } /* Name.Variable.Magic */
# body .il { color: #2aa198 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">SELECT</span> <span class="nv">?companyName</span> <span class="nv">?companyTicker</span>
# <span class="k">WHERE</span> <span class="p">{</span>
#   <span class="c"># Select companies in the ETF with ticker &#39;URTH&#39;</span>
#   <span class="nv">?urthEtf</span> <span class="nn">rdf</span><span class="p">:</span><span class="nt">type</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">ETF</span> <span class="p">;</span>
#            <span class="nn">finance</span><span class="p">:</span><span class="nt">hasTicker</span> <span class="s">&quot;URTH&quot;</span> <span class="p">;</span>
#            <span class="nn">finance</span><span class="p">:</span><span class="nt">hasCompany</span> <span class="nv">?company</span> <span class="p">.</span>
#
#   <span class="c"># Check if the company is not in the ETF with ticker &#39;IVV&#39;</span>
#   <span class="k">FILTER</span> <span class="nf">NOT EXISTS</span> <span class="p">{</span>
#     <span class="nv">?ivvEtf</span> <span class="nn">rdf</span><span class="p">:</span><span class="nt">type</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">ETF</span> <span class="p">;</span>
#             <span class="nn">finance</span><span class="p">:</span><span class="nt">hasTicker</span> <span class="s">&quot;IVV&quot;</span> <span class="p">;</span>
#             <span class="nn">finance</span><span class="p">:</span><span class="nt">hasCompany</span> <span class="nv">?company</span> <span class="p">.</span>
#   <span class="p">}</span>
#
#   <span class="c"># Get the name and ticker of the company</span>
#   <span class="nv">?company</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">hasName</span> <span class="nv">?companyName</span> <span class="p">;</span>
#            <span class="nn">finance</span><span class="p">:</span><span class="nt">hasTicker</span> <span class="nv">?companyTicker</span> <span class="p">.</span>
# <span class="p">}</span>
# </pre></div>
# </body>
# </html>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>companyName</th>
#       <th>companyTicker</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>LEGAL &amp; GENERAL GROUP</td>
#       <td>LGGNF</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>SCOUT24 SE</td>
#       <td>SCOTF</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>KESKO OYJ</td>
#       <td>KKOYF</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>TOHO CO LTD</td>
#       <td>TKCOF</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>TFI International Inc.</td>
#       <td>TFII</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>ATLAS COPCO AB</td>
#       <td>ATLPF</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>JARDINE MATHESON HLDGS</td>
#       <td>JARLF</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>TELSTRA GROUP LIMITED</td>
#       <td>TTRAF</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>ENTAIN PLC</td>
#       <td>GMVHF</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>DAIMLER TRUCK HOLDING AG</td>
#       <td>DTGHF</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>GJENSIDIGE FORSIKRING ASA</td>
#       <td>GJNSF</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>ASAHI INTECC CO LTD</td>
#       <td>AHICF</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>KLEPIERRE</td>
#       <td>KLPEF</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>UNITED UTILITIES GROUP PLC</td>
#       <td>UUGWF</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>CARL ZEISS MEDITEC AG</td>
#       <td>CZMWF</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>COMPAGNIE FINANCIERE RICHEMONT</td>
#       <td>CFRHF</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>OMRON CORP</td>
#       <td>OMRNF</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>SVENSKA CELLULOSA AB-SCA</td>
#       <td>SVCBF</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>SEATRIUM LTD</td>
#       <td>SMBMF</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>LEG IMMOBILIEN SE</td>
#       <td>LEGIF</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>KERRY GROUP</td>
#       <td>KRYAF</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>MTR CORPORATION LTD</td>
#       <td>MTRJF</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>Deutsche Bank AG</td>
#       <td>DB</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>Paylocity Holding Corporation</td>
#       <td>PCTY</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>VEOLIA ENVIRONNEMENT</td>
#       <td>VEOEF</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>L'OREAL</td>
#       <td>LRLCF</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>KEPPEL LTD</td>
#       <td>KPELF</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>REXEL</td>
#       <td>RXLSF</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>MITSUI CHEMICALS INC</td>
#       <td>MITUF</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>Manhattan Associates, Inc.</td>
#       <td>MANH</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>NEC CORP</td>
#       <td>NIPNF</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>CENTRAL JAPAN RAILWAY CO</td>
#       <td>CJPRF</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>JAMES HARDIE INDUSTRIES PLC CDI</td>
#       <td>JHIUF</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>GETLINK SE</td>
#       <td>GRPTF</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>STANDARD CHARTERED PLC</td>
#       <td>SCBFF</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>SS&amp;C Technologies Holdings, Inc</td>
#       <td>SSNC</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>JD SPORTS FASHION PLC</td>
#       <td>JDDSF</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>NOVO NORDISK A/S</td>
#       <td>NONOF</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>EIFFAGE</td>
#       <td>EFGSF</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>AECOM</td>
#       <td>ACM</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>American Homes 4 Rent</td>
#       <td>AMH</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>YARA INTERNATIONAL ASA</td>
#       <td>YRAIF</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>HOSHIZAKI CORPORATION</td>
#       <td>HSHIF</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>NESTE OYJ</td>
#       <td>NTOIF</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>SSE PLC</td>
#       <td>SSEZF</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>BURBERRY GROUP</td>
#       <td>BBRYF</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>KONINKLIJKE PHILIPS NV</td>
#       <td>RYLPF</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>SECURITAS AB</td>
#       <td>SCTBF</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>SKANDINAVISKA ENSKILDA BANKEN</td>
#       <td>SVKEF</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>NIPPON BUILDING FUND INC</td>
#       <td>NBFJF</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>ZOZO INC</td>
#       <td>SATLF</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>SANDS CHINA LTD</td>
#       <td>SCHYF</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>BOLLORE SE</td>
#       <td>BOIVF</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>TELE2 AB</td>
#       <td>TLTZF</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>RIO TINTO</td>
#       <td>RTPPF</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>NORDEA BANK ABP</td>
#       <td>NBNKF</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>TOKYO GAS CO</td>
#       <td>TKGSF</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>ENI SPA</td>
#       <td>EIPAF</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>KOMATSU</td>
#       <td>KMTUF</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>IVANHOE MINES LTD</td>
#       <td>IVPAF</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>SUMITOMO MITSUI TRUST HOLDINGS</td>
#       <td>CMTDF</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>ASAHI KASEI CORP</td>
#       <td>AHKSF</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>Avantor, Inc.</td>
#       <td>AVTR</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>AIR LIQUIDE(L')</td>
#       <td>AIQUF</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>BLUESCOPE STEEL LTD</td>
#       <td>BLSFF</td>
#     </tr>
#     <tr>
#       <th>65</th>
#       <td>Coca-Cola Europacific Partners</td>
#       <td>CCEP</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>YAMATO HOLDINGS CO LTD</td>
#       <td>YATRF</td>
#     </tr>
#     <tr>
#       <th>67</th>
#       <td>AMPOL LTD</td>
#       <td>CTXAF</td>
#     </tr>
#     <tr>
#       <th>68</th>
#       <td>BECHTLE AG</td>
#       <td>BHTLF</td>
#     </tr>
#     <tr>
#       <th>69</th>
#       <td>SIEMENS ENERGY AG</td>
#       <td>SMEGF</td>
#     </tr>
#     <tr>
#       <th>70</th>
#       <td>LINK REAL ESTATE INVESTMENT TRU</td>
#       <td>LKREF</td>
#     </tr>
#     <tr>
#       <th>71</th>
#       <td>KAO CORP</td>
#       <td>KAOCF</td>
#     </tr>
#     <tr>
#       <th>72</th>
#       <td>ATLAS COPCO AB</td>
#       <td>ATLFF</td>
#     </tr>
#     <tr>
#       <th>73</th>
#       <td>Magna International, Inc.</td>
#       <td>MGA</td>
#     </tr>
#     <tr>
#       <th>74</th>
#       <td>EBOS GROUP</td>
#       <td>EBOSF</td>
#     </tr>
#     <tr>
#       <th>75</th>
#       <td>NOMURA RESEARCH INSTITUTE</td>
#       <td>NURAF</td>
#     </tr>
#     <tr>
#       <th>76</th>
#       <td>BRITISH AMERICAN TOBACCO</td>
#       <td>BTAFF</td>
#     </tr>
#     <tr>
#       <th>77</th>
#       <td>Cloudflare, Inc.</td>
#       <td>NET</td>
#     </tr>
#     <tr>
#       <th>78</th>
#       <td>SHARP CORP</td>
#       <td>SHCAF</td>
#     </tr>
#     <tr>
#       <th>79</th>
#       <td>ANA HOLDINGS INC</td>
#       <td>ALNPF</td>
#     </tr>
#     <tr>
#       <th>80</th>
#       <td>MIRVAC GROUP</td>
#       <td>MRVGF</td>
#     </tr>
#     <tr>
#       <th>81</th>
#       <td>ORION CORPORATION</td>
#       <td>ORINF</td>
#     </tr>
#     <tr>
#       <th>82</th>
#       <td>YAKULT HONSHA CO</td>
#       <td>YKLTF</td>
#     </tr>
#     <tr>
#       <th>83</th>
#       <td>SHIMADZU CORP</td>
#       <td>SHMZF</td>
#     </tr>
#     <tr>
#       <th>84</th>
#       <td>Cleveland-Cliffs Inc.</td>
#       <td>CLF</td>
#     </tr>
#     <tr>
#       <th>85</th>
#       <td>HEIDELBERG MATERIALS</td>
#       <td>HLBZF</td>
#     </tr>
#     <tr>
#       <th>86</th>

# %%
run_query(g, '../queries/IVV_companies_country.rq')
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #073642 }
# body .c { color: #586e75; font-style: italic } /* Comment */
# body .err { color: #839496; background-color: #dc322f } /* Error */
# body .esc { color: #839496 } /* Escape */
# body .g { color: #839496 } /* Generic */
# body .k { color: #859900 } /* Keyword */
# body .l { color: #839496 } /* Literal */
# body .n { color: #839496 } /* Name */
# body .o { color: #586e75 } /* Operator */
# body .x { color: #839496 } /* Other */
# body .p { color: #839496 } /* Punctuation */
# body .ch { color: #586e75; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #586e75; font-style: italic } /* Comment.Multiline */
# body .cp { color: #d33682 } /* Comment.Preproc */
# body .cpf { color: #586e75 } /* Comment.PreprocFile */
# body .c1 { color: #586e75; font-style: italic } /* Comment.Single */
# body .cs { color: #586e75; font-style: italic } /* Comment.Special */
# body .gd { color: #dc322f } /* Generic.Deleted */
# body .ge { color: #839496; font-style: italic } /* Generic.Emph */
# body .ges { color: #839496; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# body .gr { color: #dc322f } /* Generic.Error */
# body .gh { color: #839496; font-weight: bold } /* Generic.Heading */
# body .gi { color: #859900 } /* Generic.Inserted */
# body .go { color: #839496 } /* Generic.Output */
# body .gp { color: #268bd2; font-weight: bold } /* Generic.Prompt */
# body .gs { color: #839496; font-weight: bold } /* Generic.Strong */
# body .gu { color: #839496; text-decoration: underline } /* Generic.Subheading */
# body .gt { color: #268bd2 } /* Generic.Traceback */
# body .kc { color: #2aa198 } /* Keyword.Constant */
# body .kd { color: #2aa198 } /* Keyword.Declaration */
# body .kn { color: #cb4b16 } /* Keyword.Namespace */
# body .kp { color: #859900 } /* Keyword.Pseudo */
# body .kr { color: #859900 } /* Keyword.Reserved */
# body .kt { color: #b58900 } /* Keyword.Type */
# body .ld { color: #839496 } /* Literal.Date */
# body .m { color: #2aa198 } /* Literal.Number */
# body .s { color: #2aa198 } /* Literal.String */
# body .na { color: #839496 } /* Name.Attribute */
# body .nb { color: #268bd2 } /* Name.Builtin */
# body .nc { color: #268bd2 } /* Name.Class */
# body .no { color: #268bd2 } /* Name.Constant */
# body .nd { color: #268bd2 } /* Name.Decorator */
# body .ni { color: #268bd2 } /* Name.Entity */
# body .ne { color: #268bd2 } /* Name.Exception */
# body .nf { color: #268bd2 } /* Name.Function */
# body .nl { color: #268bd2 } /* Name.Label */
# body .nn { color: #268bd2 } /* Name.Namespace */
# body .nx { color: #839496 } /* Name.Other */
# body .py { color: #839496 } /* Name.Property */
# body .nt { color: #268bd2 } /* Name.Tag */
# body .nv { color: #268bd2 } /* Name.Variable */
# body .ow { color: #859900 } /* Operator.Word */
# body .pm { color: #839496 } /* Punctuation.Marker */
# body .w { color: #839496 } /* Text.Whitespace */
# body .mb { color: #2aa198 } /* Literal.Number.Bin */
# body .mf { color: #2aa198 } /* Literal.Number.Float */
# body .mh { color: #2aa198 } /* Literal.Number.Hex */
# body .mi { color: #2aa198 } /* Literal.Number.Integer */
# body .mo { color: #2aa198 } /* Literal.Number.Oct */
# body .sa { color: #2aa198 } /* Literal.String.Affix */
# body .sb { color: #2aa198 } /* Literal.String.Backtick */
# body .sc { color: #2aa198 } /* Literal.String.Char */
# body .dl { color: #2aa198 } /* Literal.String.Delimiter */
# body .sd { color: #586e75 } /* Literal.String.Doc */
# body .s2 { color: #2aa198 } /* Literal.String.Double */
# body .se { color: #2aa198 } /* Literal.String.Escape */
# body .sh { color: #2aa198 } /* Literal.String.Heredoc */
# body .si { color: #2aa198 } /* Literal.String.Interpol */
# body .sx { color: #2aa198 } /* Literal.String.Other */
# body .sr { color: #cb4b16 } /* Literal.String.Regex */
# body .s1 { color: #2aa198 } /* Literal.String.Single */
# body .ss { color: #2aa198 } /* Literal.String.Symbol */
# body .bp { color: #268bd2 } /* Name.Builtin.Pseudo */
# body .fm { color: #268bd2 } /* Name.Function.Magic */
# body .vc { color: #268bd2 } /* Name.Variable.Class */
# body .vg { color: #268bd2 } /* Name.Variable.Global */
# body .vi { color: #268bd2 } /* Name.Variable.Instance */
# body .vm { color: #268bd2 } /* Name.Variable.Magic */
# body .il { color: #2aa198 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">SELECT</span> <span class="nv">?country</span> <span class="p">(</span><span class="nf">COUNT</span><span class="p">(</span><span class="k">DISTINCT</span> <span class="nv">?company</span><span class="p">)</span> <span class="k">AS</span> <span class="nv">?companyCount</span><span class="p">)</span>
# <span class="k">WHERE</span> <span class="p">{</span>
#   <span class="c"># Specify the ETF of interest (replace &#39;IVV&#39; with the desired ETF ticker)</span>
#   <span class="nv">?etf</span> <span class="nn">rdf</span><span class="p">:</span><span class="nt">type</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">ETF</span> <span class="p">;</span>
#        <span class="nn">finance</span><span class="p">:</span><span class="nt">hasTicker</span> <span class="s">&quot;IVV&quot;</span> <span class="p">;</span>
#        <span class="nn">finance</span><span class="p">:</span><span class="nt">hasCompany</span> <span class="nv">?company</span> <span class="p">.</span>
#
#   <span class="c"># Get the address of each company</span>
#   <span class="nv">?company</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">hasAddress</span> <span class="nv">?address</span> <span class="p">.</span>
#
#   <span class="c"># Extract the country from the address</span>
#   <span class="nv">?address</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">hasCountry</span> <span class="nv">?country</span> <span class="p">.</span>
# <span class="p">}</span>
# <span class="k">GROUP BY</span> <span class="nv">?country</span>
# <span class="k">ORDER BY</span> <span class="k">DESC</span><span class="p">(</span><span class="nv">?companyCount</span><span class="p">)</span>
# </pre></div>
# </body>
# </html>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>country</th>
#       <th>companyCount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>United States</td>
#       <td>481</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Ireland</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Switzerland</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>United Kingdom</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Bermuda</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Netherlands</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Canada</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>

# %%
run_query(g, '../queries/URTH_companies_country.rq')
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #073642 }
# body .c { color: #586e75; font-style: italic } /* Comment */
# body .err { color: #839496; background-color: #dc322f } /* Error */
# body .esc { color: #839496 } /* Escape */
# body .g { color: #839496 } /* Generic */
# body .k { color: #859900 } /* Keyword */
# body .l { color: #839496 } /* Literal */
# body .n { color: #839496 } /* Name */
# body .o { color: #586e75 } /* Operator */
# body .x { color: #839496 } /* Other */
# body .p { color: #839496 } /* Punctuation */
# body .ch { color: #586e75; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #586e75; font-style: italic } /* Comment.Multiline */
# body .cp { color: #d33682 } /* Comment.Preproc */
# body .cpf { color: #586e75 } /* Comment.PreprocFile */
# body .c1 { color: #586e75; font-style: italic } /* Comment.Single */
# body .cs { color: #586e75; font-style: italic } /* Comment.Special */
# body .gd { color: #dc322f } /* Generic.Deleted */
# body .ge { color: #839496; font-style: italic } /* Generic.Emph */
# body .ges { color: #839496; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# body .gr { color: #dc322f } /* Generic.Error */
# body .gh { color: #839496; font-weight: bold } /* Generic.Heading */
# body .gi { color: #859900 } /* Generic.Inserted */
# body .go { color: #839496 } /* Generic.Output */
# body .gp { color: #268bd2; font-weight: bold } /* Generic.Prompt */
# body .gs { color: #839496; font-weight: bold } /* Generic.Strong */
# body .gu { color: #839496; text-decoration: underline } /* Generic.Subheading */
# body .gt { color: #268bd2 } /* Generic.Traceback */
# body .kc { color: #2aa198 } /* Keyword.Constant */
# body .kd { color: #2aa198 } /* Keyword.Declaration */
# body .kn { color: #cb4b16 } /* Keyword.Namespace */
# body .kp { color: #859900 } /* Keyword.Pseudo */
# body .kr { color: #859900 } /* Keyword.Reserved */
# body .kt { color: #b58900 } /* Keyword.Type */
# body .ld { color: #839496 } /* Literal.Date */
# body .m { color: #2aa198 } /* Literal.Number */
# body .s { color: #2aa198 } /* Literal.String */
# body .na { color: #839496 } /* Name.Attribute */
# body .nb { color: #268bd2 } /* Name.Builtin */
# body .nc { color: #268bd2 } /* Name.Class */
# body .no { color: #268bd2 } /* Name.Constant */
# body .nd { color: #268bd2 } /* Name.Decorator */
# body .ni { color: #268bd2 } /* Name.Entity */
# body .ne { color: #268bd2 } /* Name.Exception */
# body .nf { color: #268bd2 } /* Name.Function */
# body .nl { color: #268bd2 } /* Name.Label */
# body .nn { color: #268bd2 } /* Name.Namespace */
# body .nx { color: #839496 } /* Name.Other */
# body .py { color: #839496 } /* Name.Property */
# body .nt { color: #268bd2 } /* Name.Tag */
# body .nv { color: #268bd2 } /* Name.Variable */
# body .ow { color: #859900 } /* Operator.Word */
# body .pm { color: #839496 } /* Punctuation.Marker */
# body .w { color: #839496 } /* Text.Whitespace */
# body .mb { color: #2aa198 } /* Literal.Number.Bin */
# body .mf { color: #2aa198 } /* Literal.Number.Float */
# body .mh { color: #2aa198 } /* Literal.Number.Hex */
# body .mi { color: #2aa198 } /* Literal.Number.Integer */
# body .mo { color: #2aa198 } /* Literal.Number.Oct */
# body .sa { color: #2aa198 } /* Literal.String.Affix */
# body .sb { color: #2aa198 } /* Literal.String.Backtick */
# body .sc { color: #2aa198 } /* Literal.String.Char */
# body .dl { color: #2aa198 } /* Literal.String.Delimiter */
# body .sd { color: #586e75 } /* Literal.String.Doc */
# body .s2 { color: #2aa198 } /* Literal.String.Double */
# body .se { color: #2aa198 } /* Literal.String.Escape */
# body .sh { color: #2aa198 } /* Literal.String.Heredoc */
# body .si { color: #2aa198 } /* Literal.String.Interpol */
# body .sx { color: #2aa198 } /* Literal.String.Other */
# body .sr { color: #cb4b16 } /* Literal.String.Regex */
# body .s1 { color: #2aa198 } /* Literal.String.Single */
# body .ss { color: #2aa198 } /* Literal.String.Symbol */
# body .bp { color: #268bd2 } /* Name.Builtin.Pseudo */
# body .fm { color: #268bd2 } /* Name.Function.Magic */
# body .vc { color: #268bd2 } /* Name.Variable.Class */
# body .vg { color: #268bd2 } /* Name.Variable.Global */
# body .vi { color: #268bd2 } /* Name.Variable.Instance */
# body .vm { color: #268bd2 } /* Name.Variable.Magic */
# body .il { color: #2aa198 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">SELECT</span> <span class="nv">?country</span> <span class="p">(</span><span class="nf">COUNT</span><span class="p">(</span><span class="k">DISTINCT</span> <span class="nv">?company</span><span class="p">)</span> <span class="k">AS</span> <span class="nv">?companyCount</span><span class="p">)</span>
# <span class="k">WHERE</span> <span class="p">{</span>
#   <span class="nv">?etf</span> <span class="nn">rdf</span><span class="p">:</span><span class="nt">type</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">ETF</span> <span class="p">;</span>
#        <span class="nn">finance</span><span class="p">:</span><span class="nt">hasTicker</span> <span class="s">&quot;URTH&quot;</span> <span class="p">;</span>
#        <span class="nn">finance</span><span class="p">:</span><span class="nt">hasCompany</span> <span class="nv">?company</span> <span class="p">.</span>
#
#   <span class="c"># Get the address of each company</span>
#   <span class="nv">?company</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">hasAddress</span> <span class="nv">?address</span> <span class="p">.</span>
#
#   <span class="c"># Extract the country from the address</span>
#   <span class="nv">?address</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">hasCountry</span> <span class="nv">?country</span> <span class="p">.</span>
# <span class="p">}</span>
# <span class="k">GROUP BY</span> <span class="nv">?country</span>
# <span class="k">ORDER BY</span> <span class="k">DESC</span><span class="p">(</span><span class="nv">?companyCount</span><span class="p">)</span>
# </pre></div>
# </body>
# </html>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>country</th>
#       <th>companyCount</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>United States</td>
#       <td>572</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Japan</td>
#       <td>214</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Canada</td>
#       <td>86</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>United Kingdom</td>
#       <td>79</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>France</td>
#       <td>56</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Germany</td>
#       <td>55</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Australia</td>
#       <td>54</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Switzerland</td>
#       <td>53</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Sweden</td>
#       <td>41</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Netherlands</td>
#       <td>29</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Hong Kong</td>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Ireland</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Italy</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Singapore</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Spain</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Israel</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Denmark</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Finland</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Norway</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Belgium</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>New Zealand</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>Bermuda</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>Austria</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>Portugal</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>Luxembourg</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>Macau</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>Isle of Man</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>Uruguay</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>

# %%
run_query(g, '../queries/IVV_sectors.rq')
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #073642 }
# body .c { color: #586e75; font-style: italic } /* Comment */
# body .err { color: #839496; background-color: #dc322f } /* Error */
# body .esc { color: #839496 } /* Escape */
# body .g { color: #839496 } /* Generic */
# body .k { color: #859900 } /* Keyword */
# body .l { color: #839496 } /* Literal */
# body .n { color: #839496 } /* Name */
# body .o { color: #586e75 } /* Operator */
# body .x { color: #839496 } /* Other */
# body .p { color: #839496 } /* Punctuation */
# body .ch { color: #586e75; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #586e75; font-style: italic } /* Comment.Multiline */
# body .cp { color: #d33682 } /* Comment.Preproc */
# body .cpf { color: #586e75 } /* Comment.PreprocFile */
# body .c1 { color: #586e75; font-style: italic } /* Comment.Single */
# body .cs { color: #586e75; font-style: italic } /* Comment.Special */
# body .gd { color: #dc322f } /* Generic.Deleted */
# body .ge { color: #839496; font-style: italic } /* Generic.Emph */
# body .ges { color: #839496; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# body .gr { color: #dc322f } /* Generic.Error */
# body .gh { color: #839496; font-weight: bold } /* Generic.Heading */
# body .gi { color: #859900 } /* Generic.Inserted */
# body .go { color: #839496 } /* Generic.Output */
# body .gp { color: #268bd2; font-weight: bold } /* Generic.Prompt */
# body .gs { color: #839496; font-weight: bold } /* Generic.Strong */
# body .gu { color: #839496; text-decoration: underline } /* Generic.Subheading */
# body .gt { color: #268bd2 } /* Generic.Traceback */
# body .kc { color: #2aa198 } /* Keyword.Constant */
# body .kd { color: #2aa198 } /* Keyword.Declaration */
# body .kn { color: #cb4b16 } /* Keyword.Namespace */
# body .kp { color: #859900 } /* Keyword.Pseudo */
# body .kr { color: #859900 } /* Keyword.Reserved */
# body .kt { color: #b58900 } /* Keyword.Type */
# body .ld { color: #839496 } /* Literal.Date */
# body .m { color: #2aa198 } /* Literal.Number */
# body .s { color: #2aa198 } /* Literal.String */
# body .na { color: #839496 } /* Name.Attribute */
# body .nb { color: #268bd2 } /* Name.Builtin */
# body .nc { color: #268bd2 } /* Name.Class */
# body .no { color: #268bd2 } /* Name.Constant */
# body .nd { color: #268bd2 } /* Name.Decorator */
# body .ni { color: #268bd2 } /* Name.Entity */
# body .ne { color: #268bd2 } /* Name.Exception */
# body .nf { color: #268bd2 } /* Name.Function */
# body .nl { color: #268bd2 } /* Name.Label */
# body .nn { color: #268bd2 } /* Name.Namespace */
# body .nx { color: #839496 } /* Name.Other */
# body .py { color: #839496 } /* Name.Property */
# body .nt { color: #268bd2 } /* Name.Tag */
# body .nv { color: #268bd2 } /* Name.Variable */
# body .ow { color: #859900 } /* Operator.Word */
# body .pm { color: #839496 } /* Punctuation.Marker */
# body .w { color: #839496 } /* Text.Whitespace */
# body .mb { color: #2aa198 } /* Literal.Number.Bin */
# body .mf { color: #2aa198 } /* Literal.Number.Float */
# body .mh { color: #2aa198 } /* Literal.Number.Hex */
# body .mi { color: #2aa198 } /* Literal.Number.Integer */
# body .mo { color: #2aa198 } /* Literal.Number.Oct */
# body .sa { color: #2aa198 } /* Literal.String.Affix */
# body .sb { color: #2aa198 } /* Literal.String.Backtick */
# body .sc { color: #2aa198 } /* Literal.String.Char */
# body .dl { color: #2aa198 } /* Literal.String.Delimiter */
# body .sd { color: #586e75 } /* Literal.String.Doc */
# body .s2 { color: #2aa198 } /* Literal.String.Double */
# body .se { color: #2aa198 } /* Literal.String.Escape */
# body .sh { color: #2aa198 } /* Literal.String.Heredoc */
# body .si { color: #2aa198 } /* Literal.String.Interpol */
# body .sx { color: #2aa198 } /* Literal.String.Other */
# body .sr { color: #cb4b16 } /* Literal.String.Regex */
# body .s1 { color: #2aa198 } /* Literal.String.Single */
# body .ss { color: #2aa198 } /* Literal.String.Symbol */
# body .bp { color: #268bd2 } /* Name.Builtin.Pseudo */
# body .fm { color: #268bd2 } /* Name.Function.Magic */
# body .vc { color: #268bd2 } /* Name.Variable.Class */
# body .vg { color: #268bd2 } /* Name.Variable.Global */
# body .vi { color: #268bd2 } /* Name.Variable.Instance */
# body .vm { color: #268bd2 } /* Name.Variable.Magic */
# body .il { color: #2aa198 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">SELECT</span> <span class="nv">?sectorName</span> <span class="p">((</span><span class="nf">COUNT</span><span class="p">(</span><span class="nv">?company</span><span class="p">)</span> <span class="o">*</span> <span class="mf">100.0</span> <span class="o">/</span> <span class="nv">?totalCompanies</span><span class="p">)</span> <span class="k">AS</span> <span class="nv">?sectorPercentage</span><span class="p">)</span>
# <span class="k">WHERE</span> <span class="p">{</span>
#   <span class="p">{</span>
#     <span class="k">SELECT</span> <span class="p">(</span><span class="nf">COUNT</span><span class="p">(</span><span class="nv">?company</span><span class="p">)</span> <span class="k">AS</span> <span class="nv">?totalCompanies</span><span class="p">)</span>
#     <span class="k">WHERE</span> <span class="p">{</span>
#       <span class="nv">?etf</span> <span class="k">a</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">ETF</span> <span class="p">;</span>
#            <span class="nn">finance</span><span class="p">:</span><span class="nt">hasTicker</span> <span class="s">&quot;IVV&quot;</span> <span class="p">.</span>
#       <span class="nv">?etf</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">hasCompany</span> <span class="nv">?company</span> <span class="p">.</span>
#     <span class="p">}</span>
#   <span class="p">}</span>
#   <span class="nv">?etf</span> <span class="k">a</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">ETF</span> <span class="p">;</span>
#        <span class="nn">finance</span><span class="p">:</span><span class="nt">hasTicker</span> <span class="s">&quot;IVV&quot;</span> <span class="p">.</span>
#   <span class="nv">?etf</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">hasCompany</span> <span class="nv">?company</span> <span class="p">.</span>
#   <span class="nv">?company</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">hasIndustry</span> <span class="nv">?industry</span> <span class="p">.</span>
#   <span class="nv">?industry</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">belongsToSector</span> <span class="nv">?sector</span> <span class="p">.</span>
#   <span class="nv">?sector</span> <span class="nn">rdfs</span><span class="p">:</span><span class="nt">label</span> <span class="nv">?sectorName</span> <span class="p">.</span>
# <span class="p">}</span>
# <span class="k">GROUP BY</span> <span class="nv">?sectorName</span> <span class="nv">?totalCompanies</span>
# <span class="k">ORDER BY</span> <span class="k">DESC</span><span class="p">(</span><span class="nv">?sectorPercentage</span><span clas
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sectorName</th>
#       <th>sectorPercentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Technology</td>
#       <td>14.74103585657370511</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Industrials</td>
#       <td>14.541832669322709095</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Financial Services</td>
#       <td>13.54581673306772902</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Healthcare</td>
#       <td>12.948207171314740975</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Consumer Cyclical</td>
#       <td>11.354581673306772855</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Consumer Defensive</td>
#       <td>7.370517928286852555</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Real Estate</td>
#       <td>6.175298804780876465</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Utilities</td>
#       <td>5.97609561752988045</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Energy</td>
#       <td>4.581673306772908345</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Basic Materials</td>
#       <td>4.38247011952191233</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Communication Services</td>
#       <td>4.38247011952191233</td>
#     </tr>
#   </tbody>
# </table>

# %%
run_query(g, '../queries/URTH_sectors.rq')
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #073642 }
# body .c { color: #586e75; font-style: italic } /* Comment */
# body .err { color: #839496; background-color: #dc322f } /* Error */
# body .esc { color: #839496 } /* Escape */
# body .g { color: #839496 } /* Generic */
# body .k { color: #859900 } /* Keyword */
# body .l { color: #839496 } /* Literal */
# body .n { color: #839496 } /* Name */
# body .o { color: #586e75 } /* Operator */
# body .x { color: #839496 } /* Other */
# body .p { color: #839496 } /* Punctuation */
# body .ch { color: #586e75; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #586e75; font-style: italic } /* Comment.Multiline */
# body .cp { color: #d33682 } /* Comment.Preproc */
# body .cpf { color: #586e75 } /* Comment.PreprocFile */
# body .c1 { color: #586e75; font-style: italic } /* Comment.Single */
# body .cs { color: #586e75; font-style: italic } /* Comment.Special */
# body .gd { color: #dc322f } /* Generic.Deleted */
# body .ge { color: #839496; font-style: italic } /* Generic.Emph */
# body .ges { color: #839496; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# body .gr { color: #dc322f } /* Generic.Error */
# body .gh { color: #839496; font-weight: bold } /* Generic.Heading */
# body .gi { color: #859900 } /* Generic.Inserted */
# body .go { color: #839496 } /* Generic.Output */
# body .gp { color: #268bd2; font-weight: bold } /* Generic.Prompt */
# body .gs { color: #839496; font-weight: bold } /* Generic.Strong */
# body .gu { color: #839496; text-decoration: underline } /* Generic.Subheading */
# body .gt { color: #268bd2 } /* Generic.Traceback */
# body .kc { color: #2aa198 } /* Keyword.Constant */
# body .kd { color: #2aa198 } /* Keyword.Declaration */
# body .kn { color: #cb4b16 } /* Keyword.Namespace */
# body .kp { color: #859900 } /* Keyword.Pseudo */
# body .kr { color: #859900 } /* Keyword.Reserved */
# body .kt { color: #b58900 } /* Keyword.Type */
# body .ld { color: #839496 } /* Literal.Date */
# body .m { color: #2aa198 } /* Literal.Number */
# body .s { color: #2aa198 } /* Literal.String */
# body .na { color: #839496 } /* Name.Attribute */
# body .nb { color: #268bd2 } /* Name.Builtin */
# body .nc { color: #268bd2 } /* Name.Class */
# body .no { color: #268bd2 } /* Name.Constant */
# body .nd { color: #268bd2 } /* Name.Decorator */
# body .ni { color: #268bd2 } /* Name.Entity */
# body .ne { color: #268bd2 } /* Name.Exception */
# body .nf { color: #268bd2 } /* Name.Function */
# body .nl { color: #268bd2 } /* Name.Label */
# body .nn { color: #268bd2 } /* Name.Namespace */
# body .nx { color: #839496 } /* Name.Other */
# body .py { color: #839496 } /* Name.Property */
# body .nt { color: #268bd2 } /* Name.Tag */
# body .nv { color: #268bd2 } /* Name.Variable */
# body .ow { color: #859900 } /* Operator.Word */
# body .pm { color: #839496 } /* Punctuation.Marker */
# body .w { color: #839496 } /* Text.Whitespace */
# body .mb { color: #2aa198 } /* Literal.Number.Bin */
# body .mf { color: #2aa198 } /* Literal.Number.Float */
# body .mh { color: #2aa198 } /* Literal.Number.Hex */
# body .mi { color: #2aa198 } /* Literal.Number.Integer */
# body .mo { color: #2aa198 } /* Literal.Number.Oct */
# body .sa { color: #2aa198 } /* Literal.String.Affix */
# body .sb { color: #2aa198 } /* Literal.String.Backtick */
# body .sc { color: #2aa198 } /* Literal.String.Char */
# body .dl { color: #2aa198 } /* Literal.String.Delimiter */
# body .sd { color: #586e75 } /* Literal.String.Doc */
# body .s2 { color: #2aa198 } /* Literal.String.Double */
# body .se { color: #2aa198 } /* Literal.String.Escape */
# body .sh { color: #2aa198 } /* Literal.String.Heredoc */
# body .si { color: #2aa198 } /* Literal.String.Interpol */
# body .sx { color: #2aa198 } /* Literal.String.Other */
# body .sr { color: #cb4b16 } /* Literal.String.Regex */
# body .s1 { color: #2aa198 } /* Literal.String.Single */
# body .ss { color: #2aa198 } /* Literal.String.Symbol */
# body .bp { color: #268bd2 } /* Name.Builtin.Pseudo */
# body .fm { color: #268bd2 } /* Name.Function.Magic */
# body .vc { color: #268bd2 } /* Name.Variable.Class */
# body .vg { color: #268bd2 } /* Name.Variable.Global */
# body .vi { color: #268bd2 } /* Name.Variable.Instance */
# body .vm { color: #268bd2 } /* Name.Variable.Magic */
# body .il { color: #2aa198 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">SELECT</span> <span class="nv">?sectorName</span> <span class="p">((</span><span class="nf">COUNT</span><span class="p">(</span><span class="nv">?company</span><span class="p">)</span> <span class="o">*</span> <span class="mf">100.0</span> <span class="o">/</span> <span class="nv">?totalCompanies</span><span class="p">)</span> <span class="k">AS</span> <span class="nv">?sectorPercentage</span><span class="p">)</span>
# <span class="k">WHERE</span> <span class="p">{</span>
#   <span class="p">{</span>
#     <span class="k">SELECT</span> <span class="p">(</span><span class="nf">COUNT</span><span class="p">(</span><span class="nv">?company</span><span class="p">)</span> <span class="k">AS</span> <span class="nv">?totalCompanies</span><span class="p">)</span>
#     <span class="k">WHERE</span> <span class="p">{</span>
#       <span class="nv">?etf</span> <span class="k">a</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">ETF</span> <span class="p">;</span>
#            <span class="nn">finance</span><span class="p">:</span><span class="nt">hasTicker</span> <span class="s">&quot;URTH&quot;</span> <span class="p">.</span>
#       <span class="nv">?etf</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">hasCompany</span> <span class="nv">?company</span> <span class="p">.</span>
#     <span class="p">}</span>
#   <span class="p">}</span>
#   <span class="nv">?etf</span> <span class="k">a</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">ETF</span> <span class="p">;</span>
#        <span class="nn">finance</span><span class="p">:</span><span class="nt">hasTicker</span> <span class="s">&quot;URTH&quot;</span> <span class="p">.</span>
#   <span class="nv">?etf</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">hasCompany</span> <span class="nv">?company</span> <span class="p">.</span>
#   <span class="nv">?company</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">hasIndustry</span> <span class="nv">?industry</span> <span class="p">.</span>
#   <span class="nv">?industry</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">belongsToSector</span> <span class="nv">?sector</span> <span class="p">.</span>
#   <span class="nv">?sector</span> <span class="nn">rdfs</span><span class="p">:</span><span class="nt">label</span> <span class="nv">?sectorName</span> <span class="p">.</span>
# <span class="p">}</span>
# <span class="k">GROUP BY</span> <span class="nv">?sectorName</span> <span class="nv">?totalCompanies</span>
# <span class="k">ORDER BY</span> <span class="k">DESC</span><span class="p">(</span><span class="nv">?sectorPercentage</span><span cl
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sectorName</th>
#       <th>sectorPercentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Industrials</td>
#       <td>17.626648160999305888</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Financial Services</td>
#       <td>14.989590562109645952</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Technology</td>
#       <td>11.866759195003469712</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Consumer Cyclical</td>
#       <td>10.895211658570437104</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Healthcare</td>
#       <td>9.299097848716169248</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Consumer Defensive</td>
#       <td>7.356002775850104032</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Basic Materials</td>
#       <td>6.800832755031228256</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Real Estate</td>
#       <td>6.315058986814711952</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Communication Services</td>
#       <td>5.274115197779319872</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Utilities</td>
#       <td>4.85773768216516304</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Energy</td>
#       <td>4.16377515614156832</td>
#     </tr>
#   </tbody>
# </table>

# %%
run_query(g, '../queries/highest_payed.rq')
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #073642 }
# body .c { color: #586e75; font-style: italic } /* Comment */
# body .err { color: #839496; background-color: #dc322f } /* Error */
# body .esc { color: #839496 } /* Escape */
# body .g { color: #839496 } /* Generic */
# body .k { color: #859900 } /* Keyword */
# body .l { color: #839496 } /* Literal */
# body .n { color: #839496 } /* Name */
# body .o { color: #586e75 } /* Operator */
# body .x { color: #839496 } /* Other */
# body .p { color: #839496 } /* Punctuation */
# body .ch { color: #586e75; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #586e75; font-style: italic } /* Comment.Multiline */
# body .cp { color: #d33682 } /* Comment.Preproc */
# body .cpf { color: #586e75 } /* Comment.PreprocFile */
# body .c1 { color: #586e75; font-style: italic } /* Comment.Single */
# body .cs { color: #586e75; font-style: italic } /* Comment.Special */
# body .gd { color: #dc322f } /* Generic.Deleted */
# body .ge { color: #839496; font-style: italic } /* Generic.Emph */
# body .ges { color: #839496; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# body .gr { color: #dc322f } /* Generic.Error */
# body .gh { color: #839496; font-weight: bold } /* Generic.Heading */
# body .gi { color: #859900 } /* Generic.Inserted */
# body .go { color: #839496 } /* Generic.Output */
# body .gp { color: #268bd2; font-weight: bold } /* Generic.Prompt */
# body .gs { color: #839496; font-weight: bold } /* Generic.Strong */
# body .gu { color: #839496; text-decoration: underline } /* Generic.Subheading */
# body .gt { color: #268bd2 } /* Generic.Traceback */
# body .kc { color: #2aa198 } /* Keyword.Constant */
# body .kd { color: #2aa198 } /* Keyword.Declaration */
# body .kn { color: #cb4b16 } /* Keyword.Namespace */
# body .kp { color: #859900 } /* Keyword.Pseudo */
# body .kr { color: #859900 } /* Keyword.Reserved */
# body .kt { color: #b58900 } /* Keyword.Type */
# body .ld { color: #839496 } /* Literal.Date */
# body .m { color: #2aa198 } /* Literal.Number */
# body .s { color: #2aa198 } /* Literal.String */
# body .na { color: #839496 } /* Name.Attribute */
# body .nb { color: #268bd2 } /* Name.Builtin */
# body .nc { color: #268bd2 } /* Name.Class */
# body .no { color: #268bd2 } /* Name.Constant */
# body .nd { color: #268bd2 } /* Name.Decorator */
# body .ni { color: #268bd2 } /* Name.Entity */
# body .ne { color: #268bd2 } /* Name.Exception */
# body .nf { color: #268bd2 } /* Name.Function */
# body .nl { color: #268bd2 } /* Name.Label */
# body .nn { color: #268bd2 } /* Name.Namespace */
# body .nx { color: #839496 } /* Name.Other */
# body .py { color: #839496 } /* Name.Property */
# body .nt { color: #268bd2 } /* Name.Tag */
# body .nv { color: #268bd2 } /* Name.Variable */
# body .ow { color: #859900 } /* Operator.Word */
# body .pm { color: #839496 } /* Punctuation.Marker */
# body .w { color: #839496 } /* Text.Whitespace */
# body .mb { color: #2aa198 } /* Literal.Number.Bin */
# body .mf { color: #2aa198 } /* Literal.Number.Float */
# body .mh { color: #2aa198 } /* Literal.Number.Hex */
# body .mi { color: #2aa198 } /* Literal.Number.Integer */
# body .mo { color: #2aa198 } /* Literal.Number.Oct */
# body .sa { color: #2aa198 } /* Literal.String.Affix */
# body .sb { color: #2aa198 } /* Literal.String.Backtick */
# body .sc { color: #2aa198 } /* Literal.String.Char */
# body .dl { color: #2aa198 } /* Literal.String.Delimiter */
# body .sd { color: #586e75 } /* Literal.String.Doc */
# body .s2 { color: #2aa198 } /* Literal.String.Double */
# body .se { color: #2aa198 } /* Literal.String.Escape */
# body .sh { color: #2aa198 } /* Literal.String.Heredoc */
# body .si { color: #2aa198 } /* Literal.String.Interpol */
# body .sx { color: #2aa198 } /* Literal.String.Other */
# body .sr { color: #cb4b16 } /* Literal.String.Regex */
# body .s1 { color: #2aa198 } /* Literal.String.Single */
# body .ss { color: #2aa198 } /* Literal.String.Symbol */
# body .bp { color: #268bd2 } /* Name.Builtin.Pseudo */
# body .fm { color: #268bd2 } /* Name.Function.Magic */
# body .vc { color: #268bd2 } /* Name.Variable.Class */
# body .vg { color: #268bd2 } /* Name.Variable.Global */
# body .vi { color: #268bd2 } /* Name.Variable.Instance */
# body .vm { color: #268bd2 } /* Name.Variable.Magic */
# body .il { color: #2aa198 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">SELECT</span> <span class="nv">?executiveName</span> <span class="nv">?jobTitle</span> <span class="nv">?totalPay</span> <span class="nv">?companyName</span>
# <span class="k">WHERE</span> <span class="p">{</span>
#   <span class="p">{</span>
#     <span class="c"># Query for the highest-paid male executive</span>
#     <span class="k">SELECT</span> <span class="nv">?executiveName</span> <span class="nv">?jobTitle</span> <span class="nv">?totalPay</span> <span class="nv">?companyName</span>
#     <span class="k">WHERE</span> <span class="p">{</span>
#       <span class="nv">?company</span> <span class="nn">rdf</span><span class="p">:</span><span class="nt">type</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">Company</span> <span class="p">;</span>
#                <span class="nn">finance</span><span class="p">:</span><span class="nt">hasKeyExecutive</span> <span class="nv">?executive</span> <span class="p">;</span>
#                <span class="nn">finance</span><span class="p">:</span><span class="nt">hasName</span> <span class="nv">?companyName</span> <span class="p">.</span>
#       <span class="nv">?executive</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">hasTotalPay</span> <span class="nv">?totalPay</span> <span class="p">;</span>
#                  <span class="nn">finance</span><span class="p">:</span><span class="nt">hasName</span> <span class="nv">?executiveName</span> <span class="p">;</span>
#                  <span class="nn">finance</span><span class="p">:</span><span class="nt">hasGender</span> <span class="s">&quot;m&quot;</span><span class="o">^^</span><span class="nn">xsd</span><span class="p">:</span><span class="nt">string</span> <span class="p">;</span>
#                  <span class="nn">finance</span><span class="p">:</span><span class="nt">hasJobTitle</span> <span class="nv">?jobTitle</span> <span class="p">.</span>
#     <span class="p">}</span>
#     <span class="k">ORDER BY</span> <span class="k">DESC</span><span class="p">(</span><span class="nv">?totalPay</span><span class="p">)</span>
#     <span class="k">LIMIT</span> <span class="mi">1</span>
#   <span class="p">}</span>
#   <span class="k">UNION</span>
#   <span class="p">{</span>
#     <span class="k">SELECT</span> <span class="nv">?executiveName</span> <span class="nv">?jobTitle</span> <span class="nv">?totalPay</span> <span class="nv">?companyName</span>
#     <span class="k">WHERE</span> <span class="p">{</span>
#       <span class="nv">?company</span> <span class="nn">rdf</span><span class="p">:</span><span class="nt">type</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">Company</span> <span class="p">;</span>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>executiveName</th>
#       <th>jobTitle</th>
#       <th>totalPay</th>
#       <th>companyName</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Stephen Allen Schwarzman B.A., M.B.A.</td>
#       <td>Chairman, CEO &amp; Co-Founder</td>
#       <td>119784376.0</td>
#       <td>Blackstone Inc.</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Helena  Hedblom M.Sc.</td>
#       <td>CEO, President &amp; Director</td>
#       <td>22052000.0</td>
#       <td>EPIROC AB</td>
#     </tr>
#   </tbody>
# </table>

# %%
# TODO: fix query
run_query(g, '../queries/upcoming_earnings.rq')
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #073642 }
# body .c { color: #586e75; font-style: italic } /* Comment */
# body .err { color: #839496; background-color: #dc322f } /* Error */
# body .esc { color: #839496 } /* Escape */
# body .g { color: #839496 } /* Generic */
# body .k { color: #859900 } /* Keyword */
# body .l { color: #839496 } /* Literal */
# body .n { color: #839496 } /* Name */
# body .o { color: #586e75 } /* Operator */
# body .x { color: #839496 } /* Other */
# body .p { color: #839496 } /* Punctuation */
# body .ch { color: #586e75; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #586e75; font-style: italic } /* Comment.Multiline */
# body .cp { color: #d33682 } /* Comment.Preproc */
# body .cpf { color: #586e75 } /* Comment.PreprocFile */
# body .c1 { color: #586e75; font-style: italic } /* Comment.Single */
# body .cs { color: #586e75; font-style: italic } /* Comment.Special */
# body .gd { color: #dc322f } /* Generic.Deleted */
# body .ge { color: #839496; font-style: italic } /* Generic.Emph */
# body .ges { color: #839496; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# body .gr { color: #dc322f } /* Generic.Error */
# body .gh { color: #839496; font-weight: bold } /* Generic.Heading */
# body .gi { color: #859900 } /* Generic.Inserted */
# body .go { color: #839496 } /* Generic.Output */
# body .gp { color: #268bd2; font-weight: bold } /* Generic.Prompt */
# body .gs { color: #839496; font-weight: bold } /* Generic.Strong */
# body .gu { color: #839496; text-decoration: underline } /* Generic.Subheading */
# body .gt { color: #268bd2 } /* Generic.Traceback */
# body .kc { color: #2aa198 } /* Keyword.Constant */
# body .kd { color: #2aa198 } /* Keyword.Declaration */
# body .kn { color: #cb4b16 } /* Keyword.Namespace */
# body .kp { color: #859900 } /* Keyword.Pseudo */
# body .kr { color: #859900 } /* Keyword.Reserved */
# body .kt { color: #b58900 } /* Keyword.Type */
# body .ld { color: #839496 } /* Literal.Date */
# body .m { color: #2aa198 } /* Literal.Number */
# body .s { color: #2aa198 } /* Literal.String */
# body .na { color: #839496 } /* Name.Attribute */
# body .nb { color: #268bd2 } /* Name.Builtin */
# body .nc { color: #268bd2 } /* Name.Class */
# body .no { color: #268bd2 } /* Name.Constant */
# body .nd { color: #268bd2 } /* Name.Decorator */
# body .ni { color: #268bd2 } /* Name.Entity */
# body .ne { color: #268bd2 } /* Name.Exception */
# body .nf { color: #268bd2 } /* Name.Function */
# body .nl { color: #268bd2 } /* Name.Label */
# body .nn { color: #268bd2 } /* Name.Namespace */
# body .nx { color: #839496 } /* Name.Other */
# body .py { color: #839496 } /* Name.Property */
# body .nt { color: #268bd2 } /* Name.Tag */
# body .nv { color: #268bd2 } /* Name.Variable */
# body .ow { color: #859900 } /* Operator.Word */
# body .pm { color: #839496 } /* Punctuation.Marker */
# body .w { color: #839496 } /* Text.Whitespace */
# body .mb { color: #2aa198 } /* Literal.Number.Bin */
# body .mf { color: #2aa198 } /* Literal.Number.Float */
# body .mh { color: #2aa198 } /* Literal.Number.Hex */
# body .mi { color: #2aa198 } /* Literal.Number.Integer */
# body .mo { color: #2aa198 } /* Literal.Number.Oct */
# body .sa { color: #2aa198 } /* Literal.String.Affix */
# body .sb { color: #2aa198 } /* Literal.String.Backtick */
# body .sc { color: #2aa198 } /* Literal.String.Char */
# body .dl { color: #2aa198 } /* Literal.String.Delimiter */
# body .sd { color: #586e75 } /* Literal.String.Doc */
# body .s2 { color: #2aa198 } /* Literal.String.Double */
# body .se { color: #2aa198 } /* Literal.String.Escape */
# body .sh { color: #2aa198 } /* Literal.String.Heredoc */
# body .si { color: #2aa198 } /* Literal.String.Interpol */
# body .sx { color: #2aa198 } /* Literal.String.Other */
# body .sr { color: #cb4b16 } /* Literal.String.Regex */
# body .s1 { color: #2aa198 } /* Literal.String.Single */
# body .ss { color: #2aa198 } /* Literal.String.Symbol */
# body .bp { color: #268bd2 } /* Name.Builtin.Pseudo */
# body .fm { color: #268bd2 } /* Name.Function.Magic */
# body .vc { color: #268bd2 } /* Name.Variable.Class */
# body .vg { color: #268bd2 } /* Name.Variable.Global */
# body .vi { color: #268bd2 } /* Name.Variable.Instance */
# body .vm { color: #268bd2 } /* Name.Variable.Magic */
# body .il { color: #2aa198 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">SELECT</span> <span class="nv">?company</span> <span class="nv">?companyName</span> <span class="nv">?ticker</span> <span class="nv">?oldestEarningsDate</span>
# <span class="k">WHERE</span> <span class="p">{</span>
#   <span class="nv">?company</span> <span class="nn">rdf</span><span class="p">:</span><span class="nt">type</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">Company</span> <span class="p">;</span>
#            <span class="nn">finance</span><span class="p">:</span><span class="nt">hasName</span> <span class="nv">?companyName</span> <span class="p">;</span>
#            <span class="nn">finance</span><span class="p">:</span><span class="nt">hasTicker</span> <span class="nv">?ticker</span> <span class="p">.</span>
#   <span class="nv">?company</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">hasEarningsDate</span> <span class="nv">?earningsDate</span> <span class="p">.</span>
#   <span class="nv">?earningsDate</span> <span class="nn">finance</span><span class="p">:</span><span class="nt">hasDate</span> <span class="nv">?oldestEarningsDate</span> <span class="p">.</span>
#   <span class="k">FILTER</span> <span class="p">(</span><span class="nf">BOUND</span><span class="p">(</span><span class="nv">?oldestEarningsDate</span><span class="p">))</span>
# <span class="p">}</span>
# <span class="k">ORDER BY</span> <span class="nv">?oldestEarningsDate</span>
# <span class="k">LIMIT</span> <span class="mi">1</span>
# </pre></div>
# </body>
# </html>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>company</th>
#       <th>companyName</th>
#       <th>ticker</th>
#       <th>oldestEarningsDate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>https://finance.yahoo.com/quote/CRH</td>
#       <td>CRH PLC</td>
#       <td>CRH</td>
#       <td>1995-03-08</td>
#     </tr>
#   </tbody>
# </table>
